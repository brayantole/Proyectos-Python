# %% [markdown]
# <a href="https://colab.research.google.com/github/brayantole/Proyectos-Python/blob/main/Brayan_Tole_Taller_gestion_sql_y_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gestión Básica de Inventario con SQLite3
# # Taller Gestión de Inventario con SQLite y Python
#
# Brayan Camilo Tole Yara
# Bogotá, Colombia

# %% [markdown]
# ## Instalar librerías SQLite3

# %%
# %%shell
# sudo apt-get install sqlite3
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   sqlite3-doc
# The following NEW packages will be installed:
#   sqlite3
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 769 kB of archives.
# After this operation, 1,874 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 sqlite3 amd64 3.37.2-2ubuntu0.5 [769 kB]
# Fetched 769 kB in 1s (995 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package sqlite3.
# (Reading database ... 126675 files and directories currently installed.)
# Preparing to unpack .../sqlite3_3.37.2-2ubuntu0.5_amd64.deb ...
# Unpacking sqlite3 (3.37.2-2ubuntu0.5) ...
# Setting up sqlite3 (3.37.2-2ubuntu0.5) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# ## Crear la base de datos y una tabla de inventario

# %%
import sqlite3
import random

# Crear la base de datos con SQlite
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# %% [markdown]
# #Parte1
# #PREGUNTA1
# ¿Qué acción realiza sqlite3.connect('productos.db') si el archivo no existe? ¿Y si ya existe?
#
# Si el archivo productos.db no existe: El comando lo creará automáticamente en el directorio actual.
#
# Si el archivo productos.db ya existe: El comando simplemente abrirá una conexión con esa base de datos existente, permitiéndote leer y escribir en ella.
# #PREGUNTA2
# ¿Cuál es la función del objeto "cursor"? ¿Por qué no se ejecutan los comandos directamente sobre la conexión?
#
# El objeto cursor actúa como un intermediario que permite ejecutar comandos SQL. Su función es recorrer los registros de la base de datos, ejecutar sentencias y administrar los resultados de una consulta.
#
# No se ejecutan comandos directamente sobre el objeto de conexión (conn) porque la conexión maneja el enlace con el archivo de la base de datos, mientras que el cursor maneja la ejecución de los comandos. Esta separación permite, por ejemplo, tener múltiples cursores operando de forma independiente sobre la misma conexión, lo cual es útil para gestionar transacciones complejas.

# %%
# Crear una tabla llamada 'inventario'
c.execute('''
CREATE TABLE inventario (
    id INTEGER PRIMARY KEY,
    nombre TEXT,
    categoria TEXT,
    precio DECIMAL(10, 2),
    cantidad INTEGER,
    proveedor TEXT,
    fecha_ingreso DATE,
    ubicacion TEXT
)
''')

# %% [markdown]
# #PREGUNTA3
# ¿Qué dos funciones importantes cumple INTEGER PRIMARY KEY para la columna id?
#
# Clave Primaria (PRIMARY KEY): Asegura que cada valor en la columna id sea único y no nulo. Funciona como el identificador exclusivo para cada fila de la tabla.
#
# Autoincremento (INTEGER): En SQLite, cuando una columna se define como INTEGER PRIMARY KEY, se convierte en un alias de la rowid interna. Esto significa que la columna se autoincrementará automáticamente. Si insertas un nuevo producto sin especificar un id (usando None), SQLite le asignará el siguiente número entero disponible.

# %%
# Generar datos de ejemplo para la tabla
def generar_producto(id):
    nombres = ["Producto", "Artículo", "Objeto"]
    categorias = ["Electrónica", "Hogar", "Jardín", "Moda", "Deportes"]
    proveedores = ["Proveedor1", "Proveedor2", "Proveedor3"]
    ubicaciones = ["Almacén A", "Almacén B", "Almacén C"]

    nombre = random.choice(nombres) + str(id)
    categoria = random.choice(categorias)
    precio = round(random.uniform(10.0, 500.0), 2)
    cantidad = random.randint(1, 100)
    proveedor = random.choice(proveedores)
    fecha_ingreso = f"2023-{random.randint(1, 12):02d}-{random.randint(1, 28):02d}"
    ubicacion = random.choice(ubicaciones)

    return (id, nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)

# Insertar 1000 productos en la tabla
productos = [generar_producto(i + 1) for i in range(10000)]
c.executemany('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', productos)

# Guardar cambios y cerrar la conexión
conn.commit()
conn.close()

# %% [markdown]
# #PREGUNTA4
# ¿Cuál es la ventaja de usar c.executemany() en lugar de un bucle for con c.execute()?
#
# La principal ventaja de executemany() es el rendimiento. Este método envía todos los datos a la base de datos en una sola operación, lo cual es mucho más eficiente que usar execute() dentro de un bucle.
#
# Cada llamada a execute() implica una comunicación separada con la base de datos, lo que genera una sobrecarga significativa. Para miles de registros, executemany() reduce drásticamente el tiempo de ejecución.
#
# #PREGUNTA5
# ¿Qué sucedería si se olvidara incluir la línea conn.commit()?
#
# Si se olvidara incluir conn.commit(), los datos insertados no se guardarían permanentemente en el archivo productos.db. SQLite opera con transacciones; los cambios se mantienen en un estado temporal hasta que se confirman explícitamente con commit(). Al cerrar la conexión con conn.close() sin haber hecho commit, todos los cambios de esa transacción se perderían.

# %%
print("Base de datos creada y poblada con éxito.")
# Out:
# Base de datos creada y poblada con éxito.

# %% [markdown]
# ## Consulta para mostrar todos los productos creados

# %%
import sqlite3

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Consultar todos los productos
c.execute('SELECT * FROM inventario')
productos = c.fetchall()

# Imprimir los productos
for producto in productos:
    print(producto)

# Cerrar la conexión
conn.close()
# Out:
# (1, 'Producto1', 'Moda', 204.14, 63, 'Proveedor3', '2023-07-25', 'Almacén C')
# (2, 'Objeto2', 'Deportes', 299.28, 75, 'Proveedor2', '2023-07-04', 'Almacén A')
# (3, 'Producto3', 'Moda', 115.03, 67, 'Proveedor2', '2023-01-19', 'Almacén B')
# (4, 'Objeto4', 'Jardín', 359.07, 25, 'Proveedor3', '2023-11-25', 'Almacén A')
# (5, 'Artículo5', 'Moda', 463.08, 16, 'Proveedor1', '2023-05-20', 'Almacén C')
# (6, 'Producto6', 'Hogar', 103.12, 17, 'Proveedor1', '2023-02-09', 'Almacén C')
# (7, 'Objeto7', 'Hogar', 105.86, 62, 'Proveedor1', '2023-11-15', 'Almacén B')
# (8, 'Artículo8', 'Moda', 464.74, 56, 'Proveedor2', '2023-03-20', 'Almacén A')
# (9, 'Producto9', 'Electrónica', 408.36, 93, 'Proveedor1', '2023-02-25', 'Almacén A')
# (10, 'Artículo10', 'Moda', 470.34, 68, 'Proveedor1', '2023-12-13', 'Almacén A')
# (11, 'Objeto11', 'Hogar', 449.11, 82, 'Proveedor3', '2023-11-08', 'Almacén C')
# (12, 'Producto12', 'Electrónica', 349.79, 44, 'Proveedor1', '2023-04-09', 'Almacén C')
# (13, 'Artículo13', 'Deportes', 356.02, 48, 'Proveedor3', '2023-12-25', 'Almacén A')
# (14, 'Objeto14', 'Moda', 371.44, 69, 'Proveedor1', '2023-03-27', 'Almacén A')
# (15, 'Artículo15', 'Moda', 56.03, 2, 'Proveedor2', '2023-02-13', 'Almacén A')
# (16, 'Producto16', 'Electrónica', 411.78, 12, 'Proveedor1', '2023-12-03', 'Almacén B')
# (17, 'Objeto17', 'Moda', 130.59, 89, 'Proveedor2', '2023-04-25', 'Almacén A')
# (18, 'Objeto18', 'Deportes', 360.19, 50, 'Proveedor1', '2023-12-01', 'Almacén C')
# (19, 'Objeto19', 'Electrónica', 91.93, 20, 'Proveedor3', '2023-02-07', 'Almacén C')
# (20, 'Artículo20', 'Moda', 171.19, 36, 'Proveedor1', '2023-03-19', 'Almacén C')
# (21, 'Producto21', 'Deportes', 475.88, 48, 'Proveedor1', '2023-11-07', 'Almacén C')
# (22, 'Producto22', 'Deportes', 242.59, 79, 'Proveedor3', '2023-10-17', 'Almacén A')
# (23, 'Producto23', 'Electrónica', 296.17, 42, 'Proveedor1', '2023-11-01', 'Almacén B')
# (24, 'Objeto24', 'Deportes', 366.39, 67, 'Proveedor1', '2023-02-19', 'Almacén B')
# (25, 'Objeto25', 'Hogar', 221.43, 72, 'Proveedor1', '2023-12-04', 'Almacén B')
# (26, 'Producto26', 'Hogar', 409.7, 28, 'Proveedor2', '2023-02-12', 'Almacén A')
# (27, 'Objeto27', 'Deportes', 409.79, 85, 'Proveedor2', '2023-12-01', 'Almacén B')
# (28, 'Producto28', 'Hogar', 189.85, 83, 'Proveedor2', '2023-01-28', 'Almacén A')
# (29, 'Artículo29', 'Deportes', 91.76, 62, 'Proveedor2', '2023-07-28', 'Almacén B')
# (30, 'Artículo30', 'Hogar', 114.26, 1, 'Proveedor2', '2023-09-10', 'Almacén C')
# (31, 'Artículo31', 'Deportes', 321.64, 4, 'Proveedor2', '2023-09-20', 'Almacén B')
# (32, 'Producto32', 'Hogar', 79.71, 78, 'Proveedor1', '2023-08-16', 'Almacén A')
# (33, 'Objeto33', 'Moda', 68.93, 90, 'Proveedor2', '2023-04-24', 'Almacén C')
# (34, 'Artículo34', 'Jardín', 431.68, 45, 'Proveedor1', '2023-03-25', 'Almacén C')
# (35, 'Artículo35', 'Jardín', 319.46, 95, 'Proveedor3', '2023-12-05', 'Almacén A')
# (36, 'Producto36', 'Electrónica', 119.53, 15, 'Proveedor2', '2023-05-27', 'Almacén A')
# (37, 'Objeto37', 'Electrónica', 432.49, 14, 'Proveedor2', '2023-09-09', 'Almacén B')
# (38, 'Objeto38', 'Jardín', 96.59, 42, 'Proveedor2', '2023-08-08', 'Almacén C')
# (39, 'Objeto39', 'Hogar', 448.87, 16, 'Proveedor2', '2023-12-23', 'Almacén B')
# (40, 'Objeto40', 'Electrónica', 265.35, 77, 'Proveedor3', '2023-02-12', 'Almacén A')
# (41, 'Artículo41', 'Jardín', 250.82, 69, 'Proveedor2', '2023-01-19', 'Almacén C')
# (42, 'Artículo42', 'Deportes', 161.73, 2, 'Proveedor2', '2023-11-12', 'Almacén B')
# (43, 'Producto43', 'Deportes', 459.22, 20, 'Proveedor2', '2023-07-02', 'Almacén A')
# (44, 'Artículo44', 'Electrónica', 54.72, 45, 'Proveedor1', '2023-01-16', 'Almacén A')
# (45, 'Artículo45', 'Hogar', 76.69, 17, 'Proveedor3', '2023-10-04', 'Almacén A')
# (46, 'Artículo46', 'Jardín', 148.85, 40, 'Proveedor3', '2023-06-23', 'Almacén A')
# (47, 'Producto47', 'Electrónica', 498.2, 34, 'Proveedor3', '2023-06-20', 'Almacén A')
# (48, 'Artículo48', 'Deportes', 66.2, 57, 'Proveedor3', '2023-02-07', 'Almacén A')
# (49, 'Producto49', 'Hogar', 103, 53, 'Proveedor1', '2023-06-08', 'Almacén A')
# (50, 'Artículo50', 'Moda', 305.51, 86, 'Proveedor2', '2023-07-27', 'Almacén A')
# (51, 'Objeto51', 'Jardín', 371.73, 37, 'Proveedor2', '2023-06-20', 'Almacén C')
# (52, 'Objeto52', 'Deportes', 169.69, 48, 'Proveedor1', '2023-09-03', 'Almacén C')
# (53, 'Artículo53', 'Moda', 354.82, 85, 'Proveedor1', '2023-02-19', 'Almacén B')
# (54, 'Artículo54', 'Electrónica', 215.57, 19, 'Proveedor1', '2023-02-01', 'Almacén A')
# (55, 'Producto55', 'Moda', 206.82, 87, 'Proveedor1', '2023-09-24', 'Almacén B')
# (56, 'Artículo56', 'Moda', 214.76, 91, 'Proveedor3', '2023-04-14', 'Almacén C')
# (57, 'Producto57', 'Jardín', 73.78, 68, 'Proveedor1', '2023-12-11', 'Almacén B')
# (58, 'Producto58', 'Hogar', 474.96, 12, 'Proveedor3', '2023-03-15', 'Almacén A')
# (59, 'Producto59', 'Deportes', 480.45, 74, 'Proveedor2', '2023-04-02', 'Almacén C')
# (60, 'Producto60', 'Hogar', 288.98, 44, 'Proveedor2', '2023-06-25', 'Almacén C')
# (61, 'Producto61', 'Moda', 312.94, 25, 'Proveedor3', '2023-07-16', 'Almacén A')
# (62, 'Objeto62', 'Deportes', 261.45, 2, 'Proveedor1', '2023-06-19', 'Almacén B')
# (63, 'Objeto63', 'Jardín', 401.55, 35, 'Proveedor3', '2023-09-25', 'Almacén A')
# (64, 'Artículo64', 'Jardín', 386.98, 69, 'Proveedor2', '2023-11-25', 'Almacén B')
# (65, 'Objeto65', 'Hogar', 15.79, 65, 'Proveedor1', '2023-04-10', 'Almacén C')
# (66, 'Producto66', 'Moda', 74.16, 27, 'Proveedor3', '2023-08-22', 'Almacén A')
# (67, 'Producto67', 'Jardín', 57.19, 41, 'Proveedor2', '2023-01-03', 'Almacén C')
# (68, 'Artículo68', 'Electrónica', 78.85, 30, 'Proveedor3', '2023-10-09', 'Almacén A')
# (69, 'Producto69', 'Hogar', 343.49, 98, 'Proveedor2', '2023-05-03', 'Almacén C')
# (70, 'Artículo70', 'Jardín', 189.21, 93, 'Proveedor3', '2023-01-28', 'Almacén C')
# (71, 'Producto71', 'Moda', 225.06, 35, 'Proveedor3', '2023-09-22', 'Almacén B')
# (72, 'Producto72', 'Hogar', 425.02, 64, 'Proveedor1', '2023-08-27', 'Almacén A')
# (73, 'Producto73', 'Hogar', 175.13, 33, 'Proveedor1', '2023-10-27', 'Almacén C')
# (74, 'Objeto74', 'Deportes', 27.73, 73, 'Proveedor2', '2023-09-18', 'Almacén A')
# (75, 'Producto75', 'Deportes', 309.22, 73, 'Proveedor2', '2023-02-23', 'Almacén A')
# (76, 'Producto76', 'Moda', 350.57, 11, 'Proveedor1', '2023-02-28', 'Almacén C')
# (77, 'Producto77', 'Electrónica', 150.55, 31, 'Proveedor2', '2023-05-01', 'Almacén B')
# (78, 'Objeto78', 'Deportes', 244.59, 50, 'Proveedor3', '2023-05-08', 'Almacén A')
# (79, 'Objeto79', 'Hogar', 416.68, 87, 'Proveedor2', '2023-03-28', 'Almacén C')
# (80, 'Objeto80', 'Electrónica', 332.64, 42, 'Proveedor1', '2023-09-14', 'Almacén C')
# (81, 'Producto81', 'Jardín', 263.22, 51, 'Proveedor2', '2023-05-03', 'Almacén B')
# (82, 'Artículo82', 'Jardín', 362.24, 3, 'Proveedor1', '2023-04-18', 'Almacén A')
# (83, 'Artículo83', 'Jardín', 407.23, 67, 'Proveedor2', '2023-07-02', 'Almacén B')
# (84, 'Artículo84', 'Jardín', 486.01, 61, 'Proveedor1', '2023-06-11', 'Almacén B')
# (85, 'Objeto85', 'Jardín', 194.8, 4, 'Proveedor3', '2023-02-26', 'Almacén B')
# (86, 'Objeto86', 'Electrónica', 305.75, 57, 'Proveedor3', '2023-04-12', 'Almacén C')
# (87, 'Artículo87', 'Jardín', 315.59, 78, 'Proveedor1', '2023-09-28', 'Almacén C')
# (88, 'Artículo88', 'Deportes', 106.94, 4, 'Proveedor3', '2023-01-28', 'Almacén C')
# (89, 'Producto89', 'Electrónica', 453.7, 95, 'Proveedor3', '2023-10-06', 'Almacén A')
# (90, 'Artículo90', 'Jardín', 18.48, 88, 'Proveedor1', '2023-11-18', 'Almacén B')
# (91, 'Artículo91', 'Electrónica', 293.72, 100, 'Proveedor2', '2023-03-12', 'Almacén A')
# (92, 'Artículo92', 'Moda', 184.36, 41, 'Proveedor3', '2023-11-08', 'Almacén B')
# (93, 'Objeto93', 'Hogar', 373.04, 68, 'Proveedor2', '2023-11-09', 'Almacén B')
# (94, 'Producto94', 'Hogar', 166.64, 43, 'Proveedor1', '2023-09-17', 'Almacén A')
# (95, 'Artículo95', 'Hogar', 76.53, 27, 'Proveedor3', '2023-02-12', 'Almacén A')
# (96, 'Producto96', 'Hogar', 126.17, 100, 'Proveedor1', '2023-03-25', 'Almacén A')
# (97, 'Objeto97', 'Deportes', 326.13, 3, 'Proveedor1', '2023-02-15', 'Almacén B')
# (98, 'Producto98', 'Moda', 92.81, 11, 'Proveedor2', '2023-03-05', 'Almacén B')
# (99, 'Artículo99', 'Jardín', 45.87, 99, 'Proveedor1', '2023-01-18', 'Almacén B')
# (100, 'Artículo100', 'Hogar', 355.59, 67, 'Proveedor2', '2023-11-23', 'Almacén B')
# (101, 'Objeto101', 'Hogar', 213.39, 42, 'Proveedor1', '2023-03-21', 'Almacén B')
# (102, 'Objeto102', 'Jardín', 241.3, 20, 'Proveedor1', '2023-09-07', 'Almacén B')
# (103, 'Objeto103', 'Deportes', 299.56, 80, 'Proveedor3', '2023-01-17', 'Almacén A')
# (104, 'Producto104', 'Electrónica', 331.82, 69, 'Proveedor3', '2023-12-03', 'Almacén C')
# (105, 'Objeto105', 'Jardín', 225.33, 43, 'Proveedor1', '2023-08-26', 'Almacén B')
# (106, 'Objeto106', 'Deportes', 375.12, 77, 'Proveedor3', '2023-04-19', 'Almacén B')
# (107, 'Artículo107', 'Electrónica', 119.24, 65, 'Proveedor3', '2023-12-17', 'Almacén C')
# (108, 'Objeto108', 'Jardín', 18.11, 36, 'Proveedor1', '2023-11-10', 'Almacén A')
# (109, 'Objeto109', 'Moda', 196.9, 46, 'Proveedor2', '2023-05-27', 'Almacén C')
# (110, 'Producto110', 'Electrónica', 283.13, 10, 'Proveedor2', '2023-07-13', 'Almacén C')
# (111, 'Artículo111', 'Deportes', 430.63, 25, 'Proveedor1', '2023-06-11', 'Almacén A')
# (112, 'Artículo112', 'Deportes', 91.81, 10, 'Proveedor3', '2023-02-18', 'Almacén A')
# (113, 'Producto113', 'Moda', 179.62, 9, 'Proveedor2', '2023-02-22', 'Almacén C')
# (114, 'Artículo114', 'Hogar', 412.31, 9, 'Proveedor3', '2023-03-27', 'Almacén C')
# (115, 'Objeto115', 'Hogar', 175.2, 41, 'Proveedor2', '2023-10-17', 'Almacén B')
# (116, 'Objeto116', 'Moda', 429.97, 25, 'Proveedor3', '2023-04-06', 'Almacén A')
# (117, 'Producto117', 'Moda', 314.37, 59, 'Proveedor2', '2023-11-06', 'Almacén B')
# (118, 'Producto118', 'Deportes', 136.01, 21, 'Proveedor1', '2023-05-18', 'Almacén A')
# (119, 'Producto119', 'Jardín', 450.04, 29, 'Proveedor2', '2023-04-16', 'Almacén B')
# (120, 'Artículo120', 'Moda', 325.15, 19, 'Proveedor2', '2023-02-24', 'Almacén C')
# (121, 'Objeto121', 'Deportes', 185.36, 59, 'Proveedor2', '2023-01-11', 'Almacén C')
# (122, 'Producto122', 'Deportes', 330.53, 27, 'Proveedor2', '2023-04-03', 'Almacén C')
# (123, 'Artículo123', 'Jardín', 395.34, 13, 'Proveedor1', '2023-06-18', 'Almacén B')
# (124, 'Objeto124', 'Moda', 458.14, 60, 'Proveedor1', '2023-03-26', 'Almacén B')
# (125, 'Producto125', 'Deportes', 46.22, 88, 'Proveedor2', '2023-03-17', 'Almacén A')
# (126, 'Producto126', 'Deportes', 183.52, 55, 'Proveedor2', '2023-04-04', 'Almacén A')
# (127, 'Producto127', 'Jardín', 150.93, 60, 'Proveedor1', '2023-08-23', 'Almacén A')
# (128, 'Objeto128', 'Moda', 299.95, 40, 'Proveedor2', '2023-08-01', 'Almacén A')
# (129, 'Artículo129', 'Hogar', 211.87, 46, 'Proveedor3', '2023-01-02', 'Almacén A')
# (130, 'Producto130', 'Electrónica', 316.32, 22, 'Proveedor3', '2023-03-13', 'Almacén C')
# (131, 'Objeto131', 'Jardín', 155.77, 58, 'Proveedor2', '2023-06-12', 'Almacén C')
# (132, 'Producto132', 'Hogar', 221.14, 93, 'Proveedor3', '2023-03-10', 'Almacén A')
# (133, 'Artículo133', 'Jardín', 338.73, 27, 'Proveedor2', '2023-10-15', 'Almacén A')
# (134, 'Artículo134', 'Jardín', 468.98, 45, 'Proveedor3', '2023-03-27', 'Almacén A')
# (135, 'Objeto135', 'Moda', 397.15, 73, 'Proveedor3', '2023-03-28', 'Almacén B')
# (136, 'Artículo136', 'Electrónica', 101.61, 58, 'Proveedor1', '2023-10-19', 'Almacén C')
# (137, 'Producto137', 'Deportes', 79.61, 9, 'Proveedor3', '2023-04-09', 'Almacén A')
# (138, 'Producto138', 'Hogar', 424.4, 18, 'Proveedor3', '2023-02-15', 'Almacén C')
# (139, 'Artículo139', 'Hogar', 14.37, 83, 'Proveedor1', '2023-05-23', 'Almacén B')
# (140, 'Objeto140', 'Electrónica', 213.46, 13, 'Proveedor3', '2023-11-15', 'Almacén B')
# (141, 'Producto141', 'Jardín', 44.01, 27, 'Proveedor1', '2023-07-13', 'Almacén B')
# (142, 'Objeto142', 'Moda', 360.92, 3, 'Proveedor3', '2023-10-18', 'Almacén A')
# (143, 'Producto143', 'Electrónica', 252.8, 61, 'Proveedor2', '2023-04-05', 'Almacén A')
# (144, 'Objeto144', 'Hogar', 251.06, 66, 'Proveedor1', '2023-07-01', 'Almacén B')
# (145, 'Producto145', 'Hogar', 436.46, 57, 'Proveedor1', '2023-09-19', 'Almacén B')
# (146, 'Objeto146', 'Deportes', 206.83, 7, 'Proveedor3', '2023-08-21', 'Almacén C')
# (147, 'Objeto147', 'Hogar', 105.63, 74, 'Proveedor2', '2023-08-18', 'Almacén C')
# (148, 'Producto148', 'Moda', 419.52, 10, 'Proveedor3', '2023-11-07', 'Almacén C')
# (149, 'Objeto149', 'Hogar', 34.83, 83, 'Proveedor1', '2023-01-04', 'Almacén A')
# (150, 'Artículo150', 'Jardín', 66.51, 71, 'Proveedor2', '2023-11-24', 'Almacén A')
# (151, 'Objeto151', 'Jardín', 365.02, 10, 'Proveedor2', '2023-10-23', 'Almacén B')
# (152, 'Artículo152', 'Moda', 149.95, 81, 'Proveedor3', '2023-02-25', 'Almacén C')
# (153, 'Producto153', 'Moda', 416.74, 35, 'Proveedor3', '2023-12-21', 'Almacén B')
# (154, 'Artículo154', 'Jardín', 66.46, 23, 'Proveedor2', '2023-06-14', 'Almacén B')
# (155, 'Artículo155', 'Electrónica', 137.91, 5, 'Proveedor3', '2023-12-05', 'Almacén A')
# (156, 'Artículo156', 'Electrónica', 46.53, 31, 'Proveedor2', '2023-08-28', 'Almacén B')
# (157, 'Artículo157', 'Hogar', 374.2, 44, 'Proveedor1', '2023-05-08', 'Almacén B')
# (158, 'Artículo158', 'Moda', 219.53, 7, 'Proveedor3', '2023-12-07', 'Almacén C')
# (159, 'Objeto159', 'Moda', 109.03, 60, 'Proveedor3', '2023-03-17', 'Almacén C')
# (160, 'Artículo160', 'Deportes', 346.13, 46, 'Proveedor2', '2023-06-15', 'Almacén C')
# (161, 'Producto161', 'Hogar', 144.43, 19, 'Proveedor3', '2023-12-19', 'Almacén A')
# (162, 'Objeto162', 'Deportes', 209.45, 62, 'Proveedor2', '2023-09-20', 'Almacén B')
# (163, 'Objeto163', 'Moda', 357.32, 51, 'Proveedor2', '2023-11-05', 'Almacén C')
# (164, 'Producto164', 'Electrónica', 135.07, 42, 'Proveedor1', '2023-09-06', 'Almacén A')
# (165, 'Objeto165', 'Hogar', 37.43, 21, 'Proveedor2', '2023-07-07', 'Almacén B')
# (166, 'Producto166', 'Hogar', 356.63, 8, 'Proveedor2', '2023-12-03', 'Almacén B')
# (167, 'Artículo167', 'Electrónica', 352.73, 28, 'Proveedor3', '2023-11-07', 'Almacén A')
# (168, 'Objeto168', 'Jardín', 122.05, 19, 'Proveedor3', '2023-09-24', 'Almacén A')
# (169, 'Producto169', 'Electrónica', 309.3, 40, 'Proveedor1', '2023-05-01', 'Almacén C')
# (170, 'Artículo170', 'Hogar', 152.22, 39, 'Proveedor3', '2023-11-20', 'Almacén C')
# (171, 'Objeto171', 'Electrónica', 89.22, 95, 'Proveedor3', '2023-04-16', 'Almacén A')
# (172, 'Objeto172', 'Deportes', 109.25, 67, 'Proveedor1', '2023-09-12', 'Almacén B')
# (173, 'Artículo173', 'Deportes', 393.25, 39, 'Proveedor3', '2023-02-24', 'Almacén A')
# (174, 'Producto174', 'Hogar', 132.95, 55, 'Proveedor1', '2023-10-04', 'Almacén C')
# (175, 'Artículo175', 'Electrónica', 171.4, 23, 'Proveedor2', '2023-12-15', 'Almacén A')
# (176, 'Artículo176', 'Jardín', 376.94, 35, 'Proveedor1', '2023-12-15', 'Almacén C')
# (177, 'Producto177', 'Electrónica', 290.38, 75, 'Proveedor3', '2023-12-27', 'Almacén C')
# (178, 'Artículo178', 'Moda', 240.27, 41, 'Proveedor1', '2023-09-16', 'Almacén C')
# (179, 'Artículo179', 'Jardín', 288.66, 83, 'Proveedor1', '2023-06-09', 'Almacén A')
# (180, 'Artículo180', 'Jardín', 463.86, 21, 'Proveedor1', '2023-12-13', 'Almacén C')
# (181, 'Objeto181', 'Deportes', 140.63, 68, 'Proveedor2', '2023-09-20', 'Almacén C')
# (182, 'Producto182', 'Hogar', 112.4, 100, 'Proveedor3', '2023-11-21', 'Almacén C')
# (183, 'Artículo183', 'Deportes', 66.45, 13, 'Proveedor3', '2023-04-21', 'Almacén B')
# (184, 'Producto184', 'Hogar', 76.14, 80, 'Proveedor2', '2023-06-14', 'Almacén A')
# (185, 'Objeto185', 'Moda', 217.62, 22, 'Proveedor2', '2023-06-01', 'Almacén A')
# (186, 'Objeto186', 'Hogar', 140.25, 22, 'Proveedor3', '2023-07-26', 'Almacén B')
# (187, 'Objeto187', 'Moda', 374.19, 15, 'Proveedor2', '2023-07-14', 'Almacén B')
# (188, 'Producto188', 'Jardín', 458.52, 36, 'Proveedor2', '2023-06-20', 'Almacén A')
# (189, 'Producto189', 'Jardín', 40.29, 41, 'Proveedor3', '2023-10-05', 'Almacén B')
# (190, 'Objeto190', 'Moda', 408.78, 58, 'Proveedor2', '2023-09-27', 'Almacén A')
# (191, 'Objeto191', 'Jardín', 453.21, 79, 'Proveedor3', '2023-06-20', 'Almacén C')
# (192, 'Objeto192', 'Hogar', 478.81, 87, 'Proveedor2', '2023-10-26', 'Almacén C')
# (193, 'Producto193', 'Jardín', 133.28, 20, 'Proveedor3', '2023-04-27', 'Almacén C')
# (194, 'Producto194', 'Moda', 276.2, 58, 'Proveedor2', '2023-12-27', 'Almacén B')
# (195, 'Producto195', 'Moda', 283.17, 83, 'Proveedor3', '2023-02-11', 'Almacén A')
# (196, 'Artículo196', 'Deportes', 388.98, 100, 'Proveedor2', '2023-02-04', 'Almacén B')
# (197, 'Objeto197', 'Deportes', 250.63, 66, 'Proveedor2', '2023-05-14', 'Almacén C')
# (198, 'Producto198', 'Electrónica', 37.45, 93, 'Proveedor1', '2023-08-11', 'Almacén B')
# (199, 'Objeto199', 'Electrónica', 493.35, 23, 'Proveedor1', '2023-12-14', 'Almacén B')
# (200, 'Producto200', 'Electrónica', 144.77, 69, 'Proveedor1', '2023-03-26', 'Almacén A')
# (201, 'Objeto201', 'Electrónica', 488.94, 44, 'Proveedor2', '2023-11-28', 'Almacén A')
# (202, 'Objeto202', 'Jardín', 291.3, 21, 'Proveedor2', '2023-06-14', 'Almacén B')
# (203, 'Artículo203', 'Electrónica', 15.12, 8, 'Proveedor3', '2023-04-17', 'Almacén C')
# (204, 'Producto204', 'Deportes', 147.13, 67, 'Proveedor2', '2023-06-14', 'Almacén B')
# (205, 'Producto205', 'Hogar', 351.19, 95, 'Proveedor3', '2023-10-10', 'Almacén C')
# (206, 'Artículo206', 'Hogar', 423.83, 19, 'Proveedor3', '2023-08-28', 'Almacén A')
# (207, 'Objeto207', 'Deportes', 31.58, 6, 'Proveedor3', '2023-02-25', 'Almacén B')
# (208, 'Objeto208', 'Moda', 186.57, 22, 'Proveedor2', '2023-03-18', 'Almacén A')
# (209, 'Artículo209', 'Electrónica', 238.49, 71, 'Proveedor1', '2023-01-18', 'Almacén A')
# (210, 'Artículo210', 'Jardín', 284.26, 6, 'Proveedor3', '2023-11-19', 'Almacén C')
# (211, 'Artículo211', 'Electrónica', 164.85, 77, 'Proveedor1', '2023-08-09', 'Almacén B')
# (212, 'Producto212', 'Hogar', 226.1, 89, 'Proveedor3', '2023-04-01', 'Almacén B')
# (213, 'Producto213', 'Moda', 266.93, 3, 'Proveedor2', '2023-05-23', 'Almacén C')
# (214, 'Artículo214', 'Moda', 319.34, 29, 'Proveedor2', '2023-08-24', 'Almacén C')
# (215, 'Producto215', 'Jardín', 60.08, 16, 'Proveedor3', '2023-03-07', 'Almacén C')
# (216, 'Producto216', 'Deportes', 451.58, 21, 'Proveedor2', '2023-02-01', 'Almacén C')
# (217, 'Objeto217', 'Jardín', 38.77, 42, 'Proveedor2', '2023-08-06', 'Almacén B')
# (218, 'Objeto218', 'Jardín', 56.57, 37, 'Proveedor3', '2023-05-17', 'Almacén A')
# (219, 'Producto219', 'Electrónica', 397.99, 2, 'Proveedor1', '2023-05-02', 'Almacén A')
# (220, 'Producto220', 'Electrónica', 286.39, 40, 'Proveedor2', '2023-10-16', 'Almacén B')
# (221, 'Producto221', 'Deportes', 306.22, 36, 'Proveedor1', '2023-09-14', 'Almacén C')
# (222, 'Objeto222', 'Hogar', 40.15, 84, 'Proveedor1', '2023-08-08', 'Almacén C')
# (223, 'Producto223', 'Jardín', 320.71, 6, 'Proveedor2', '2023-12-20', 'Almacén B')
# (224, 'Objeto224', 'Moda', 121.6, 34, 'Proveedor2', '2023-05-28', 'Almacén C')
# (225, 'Producto225', 'Electrónica', 122.72, 80, 'Proveedor3', '2023-12-25', 'Almacén C')
# (226, 'Objeto226', 'Deportes', 78.19, 65, 'Proveedor1', '2023-12-02', 'Almacén A')
# (227, 'Artículo227', 'Jardín', 53.12, 25, 'Proveedor3', '2023-04-22', 'Almacén A')
# (228, 'Objeto228', 'Moda', 413.85, 47, 'Proveedor2', '2023-05-07', 'Almacén A')
# (229, 'Objeto229', 'Moda', 16.62, 13, 'Proveedor2', '2023-08-02', 'Almacén B')
# (230, 'Objeto230', 'Deportes', 406.95, 8, 'Proveedor3', '2023-06-22', 'Almacén C')
# (231, 'Producto231', 'Hogar', 486.66, 29, 'Proveedor2', '2023-07-01', 'Almacén A')
# (232, 'Objeto232', 'Deportes', 85.48, 48, 'Proveedor1', '2023-09-24', 'Almacén A')
# (233, 'Objeto233', 'Hogar', 466.45, 70, 'Proveedor2', '2023-07-03', 'Almacén B')
# (234, 'Producto234', 'Hogar', 89.12, 43, 'Proveedor2', '2023-01-23', 'Almacén A')
# (235, 'Producto235', 'Jardín', 148.92, 24, 'Proveedor3', '2023-05-24', 'Almacén C')
# (236, 'Producto236', 'Jardín', 47.84, 78, 'Proveedor3', '2023-07-07', 'Almacén C')
# (237, 'Objeto237', 'Moda', 179.15, 55, 'Proveedor2', '2023-04-18', 'Almacén C')
# (238, 'Objeto238', 'Deportes', 44.44, 32, 'Proveedor3', '2023-05-02', 'Almacén B')
# (239, 'Artículo239', 'Hogar', 151.66, 1, 'Proveedor1', '2023-01-26', 'Almacén B')
# (240, 'Objeto240', 'Electrónica', 422.38, 99, 'Proveedor2', '2023-03-25', 'Almacén C')
# (241, 'Artículo241', 'Deportes', 66.13, 79, 'Proveedor3', '2023-01-16', 'Almacén B')
# (242, 'Artículo242', 'Electrónica', 470.9, 75, 'Proveedor1', '2023-04-15', 'Almacén B')
# (243, 'Objeto243', 'Jardín', 468.63, 58, 'Proveedor3', '2023-01-10', 'Almacén B')
# (244, 'Artículo244', 'Hogar', 71.24, 38, 'Proveedor1', '2023-06-17', 'Almacén B')
# (245, 'Artículo245', 'Electrónica', 51.56, 63, 'Proveedor1', '2023-04-03', 'Almacén A')
# (246, 'Producto246', 'Jardín', 318.87, 69, 'Proveedor1', '2023-06-22', 'Almacén A')
# (247, 'Artículo247', 'Electrónica', 78.39, 30, 'Proveedor3', '2023-12-04', 'Almacén A')
# (248, 'Objeto248', 'Moda', 361.3, 60, 'Proveedor1', '2023-02-18', 'Almacén C')
# (249, 'Objeto249', 'Electrónica', 37.07, 32, 'Proveedor2', '2023-01-01', 'Almacén C')
# (250, 'Artículo250', 'Electrónica', 77.32, 77, 'Proveedor2', '2023-01-27', 'Almacén A')
# (251, 'Producto251', 'Jardín', 209.06, 58, 'Proveedor2', '2023-07-13', 'Almacén A')
# (252, 'Objeto252', 'Electrónica', 324.73, 32, 'Proveedor1', '2023-10-11', 'Almacén B')
# (253, 'Objeto253', 'Hogar', 455.28, 5, 'Proveedor3', '2023-07-26', 'Almacén A')
# (254, 'Producto254', 'Jardín', 88.71, 45, 'Proveedor3', '2023-02-18', 'Almacén A')
# (255, 'Producto255', 'Moda', 259.25, 91, 'Proveedor3', '2023-09-08', 'Almacén A')
# (256, 'Objeto256', 'Hogar', 39.14, 43, 'Proveedor1', '2023-07-02', 'Almacén C')
# (257, 'Objeto257', 'Jardín', 496.3, 56, 'Proveedor1', '2023-05-06', 'Almacén B')
# (258, 'Artículo258', 'Moda', 119.27, 89, 'Proveedor3', '2023-05-15', 'Almacén C')
# (259, 'Artículo259', 'Electrónica', 380.59, 43, 'Proveedor1', '2023-03-03', 'Almacén C')
# (260, 'Producto260', 'Moda', 320.97, 3, 'Proveedor1', '2023-10-17', 'Almacén A')
# (261, 'Producto261', 'Jardín', 426.22, 79, 'Proveedor1', '2023-03-14', 'Almacén A')
# (262, 'Producto262', 'Moda', 173.3, 96, 'Proveedor2', '2023-01-14', 'Almacén C')
# (263, 'Artículo263', 'Moda', 152.75, 1, 'Proveedor3', '2023-03-22', 'Almacén B')
# (264, 'Producto264', 'Hogar', 350.13, 7, 'Proveedor1', '2023-07-25', 'Almacén A')
# (265, 'Artículo265', 'Jardín', 485.59, 66, 'Proveedor3', '2023-05-22', 'Almacén A')
# (266, 'Artículo266', 'Jardín', 29.67, 99, 'Proveedor1', '2023-04-13', 'Almacén B')
# (267, 'Artículo267', 'Deportes', 43.02, 14, 'Proveedor2', '2023-01-01', 'Almacén A')
# (268, 'Producto268', 'Deportes', 366.28, 58, 'Proveedor1', '2023-06-08', 'Almacén C')
# (269, 'Artículo269', 'Moda', 65.34, 38, 'Proveedor3', '2023-08-26', 'Almacén C')
# (270, 'Objeto270', 'Deportes', 91.93, 5, 'Proveedor1', '2023-12-14', 'Almacén C')
# (271, 'Artículo271', 'Electrónica', 326.92, 47, 'Proveedor1', '2023-02-07', 'Almacén C')
# (272, 'Artículo272', 'Hogar', 386.99, 68, 'Proveedor1', '2023-09-10', 'Almacén C')
# (273, 'Objeto273', 'Jardín', 422.77, 24, 'Proveedor2', '2023-02-23', 'Almacén A')
# (274, 'Artículo274', 'Hogar', 464.72, 82, 'Proveedor1', '2023-10-08', 'Almacén B')
# (275, 'Artículo275', 'Moda', 416.72, 46, 'Proveedor3', '2023-05-18', 'Almacén B')
# (276, 'Objeto276', 'Moda', 493.5, 39, 'Proveedor2', '2023-08-10', 'Almacén A')
# (277, 'Artículo277', 'Moda', 174.93, 33, 'Proveedor1', '2023-05-03', 'Almacén A')
# (278, 'Producto278', 'Moda', 211.14, 66, 'Proveedor1', '2023-10-07', 'Almacén B')
# (279, 'Objeto279', 'Hogar', 64.12, 43, 'Proveedor3', '2023-08-01', 'Almacén C')
# (280, 'Objeto280', 'Hogar', 426.16, 21, 'Proveedor2', '2023-02-14', 'Almacén C')
# (281, 'Producto281', 'Moda', 214.49, 24, 'Proveedor2', '2023-01-05', 'Almacén B')
# (282, 'Objeto282', 'Hogar', 373.14, 83, 'Proveedor2', '2023-08-18', 'Almacén C')
# (283, 'Artículo283', 'Hogar', 354.05, 5, 'Proveedor1', '2023-10-09', 'Almacén C')
# (284, 'Objeto284', 'Electrónica', 413.41, 82, 'Proveedor2', '2023-11-19', 'Almacén A')
# (285, 'Objeto285', 'Electrónica', 82.38, 3, 'Proveedor2', '2023-05-08', 'Almacén B')
# (286, 'Objeto286', 'Electrónica', 190.23, 58, 'Proveedor3', '2023-07-01', 'Almacén C')
# (287, 'Producto287', 'Jardín', 116.43, 15, 'Proveedor1', '2023-02-12', 'Almacén C')
# (288, 'Artículo288', 'Electrónica', 219.76, 36, 'Proveedor2', '2023-02-15', 'Almacén B')
# (289, 'Objeto289', 'Hogar', 34.32, 37, 'Proveedor1', '2023-04-25', 'Almacén B')
# (290, 'Objeto290', 'Hogar', 404.88, 63, 'Proveedor1', '2023-05-18', 'Almacén B')
# (291, 'Producto291', 'Deportes', 149.92, 53, 'Proveedor1', '2023-02-01', 'Almacén C')
# (292, 'Objeto292', 'Electrónica', 313.23, 91, 'Proveedor2', '2023-06-19', 'Almacén C')
# (293, 'Objeto293', 'Hogar', 489.13, 51, 'Proveedor3', '2023-02-09', 'Almacén A')
# (294, 'Objeto294', 'Electrónica', 289.73, 98, 'Proveedor2', '2023-12-24', 'Almacén A')
# (295, 'Objeto295', 'Moda', 252.78, 24, 'Proveedor1', '2023-06-15', 'Almacén A')
# (296, 'Objeto296', 'Electrónica', 491.5, 13, 'Proveedor2', '2023-09-12', 'Almacén C')
# (297, 'Producto297', 'Deportes', 121.31, 30, 'Proveedor1', '2023-04-17', 'Almacén A')
# (298, 'Producto298', 'Moda', 407.35, 42, 'Proveedor2', '2023-03-25', 'Almacén C')
# (299, 'Artículo299', 'Hogar', 87.54, 15, 'Proveedor2', '2023-04-22', 'Almacén A')
# (300, 'Objeto300', 'Jardín', 410.59, 17, 'Proveedor1', '2023-02-07', 'Almacén C')
# (301, 'Objeto301', 'Moda', 105.23, 89, 'Proveedor1', '2023-07-07', 'Almacén A')
# (302, 'Objeto302', 'Hogar', 272.84, 9, 'Proveedor1', '2023-09-02', 'Almacén C')
# (303, 'Artículo303', 'Moda', 231.47, 94, 'Proveedor2', '2023-01-22', 'Almacén A')
# (304, 'Artículo304', 'Deportes', 413.79, 12, 'Proveedor3', '2023-05-22', 'Almacén B')
# (305, 'Artículo305', 'Moda', 297.51, 30, 'Proveedor3', '2023-07-24', 'Almacén A')
# (306, 'Artículo306', 'Moda', 198.81, 15, 'Proveedor2', '2023-03-18', 'Almacén B')
# (307, 'Objeto307', 'Electrónica', 394.66, 54, 'Proveedor3', '2023-06-06', 'Almacén A')
# (308, 'Producto308', 'Moda', 231.06, 66, 'Proveedor3', '2023-04-10', 'Almacén C')
# (309, 'Artículo309', 'Hogar', 66.68, 51, 'Proveedor2', '2023-04-13', 'Almacén C')
# (310, 'Producto310', 'Hogar', 125.45, 43, 'Proveedor2', '2023-06-05', 'Almacén B')
# (311, 'Artículo311', 'Electrónica', 420.64, 95, 'Proveedor2', '2023-06-17', 'Almacén A')
# (312, 'Objeto312', 'Electrónica', 338.91, 100, 'Proveedor2', '2023-10-02', 'Almacén A')
# (313, 'Producto313', 'Deportes', 407.97, 59, 'Proveedor3', '2023-01-11', 'Almacén B')
# (314, 'Objeto314', 'Electrónica', 456.81, 68, 'Proveedor2', '2023-11-25', 'Almacén A')
# (315, 'Producto315', 'Electrónica', 204.79, 49, 'Proveedor1', '2023-04-05', 'Almacén C')
# (316, 'Artículo316', 'Deportes', 379.98, 100, 'Proveedor1', '2023-02-02', 'Almacén C')
# (317, 'Objeto317', 'Jardín', 190.37, 99, 'Proveedor3', '2023-09-22', 'Almacén B')
# (318, 'Objeto318', 'Hogar', 491.91, 54, 'Proveedor2', '2023-09-23', 'Almacén B')
# (319, 'Artículo319', 'Electrónica', 139.73, 62, 'Proveedor1', '2023-12-13', 'Almacén A')
# (320, 'Artículo320', 'Hogar', 405.54, 10, 'Proveedor3', '2023-12-11', 'Almacén A')
# (321, 'Artículo321', 'Hogar', 52.01, 70, 'Proveedor3', '2023-11-22', 'Almacén C')
# (322, 'Producto322', 'Deportes', 99.12, 18, 'Proveedor2', '2023-12-01', 'Almacén B')
# (323, 'Objeto323', 'Hogar', 57.57, 63, 'Proveedor2', '2023-01-14', 'Almacén B')
# (324, 'Objeto324', 'Hogar', 17.93, 80, 'Proveedor3', '2023-09-07', 'Almacén C')
# (325, 'Producto325', 'Deportes', 318.42, 17, 'Proveedor3', '2023-01-01', 'Almacén C')
# (326, 'Producto326', 'Electrónica', 240.56, 5, 'Proveedor2', '2023-11-04', 'Almacén C')
# (327, 'Producto327', 'Deportes', 273.02, 90, 'Proveedor3', '2023-08-24', 'Almacén B')
# (328, 'Artículo328', 'Deportes', 44.37, 76, 'Proveedor3', '2023-01-20', 'Almacén C')
# (329, 'Objeto329', 'Electrónica', 338.83, 14, 'Proveedor3', '2023-12-10', 'Almacén B')
# (330, 'Artículo330', 'Deportes', 481.98, 81, 'Proveedor3', '2023-10-20', 'Almacén B')
# (331, 'Objeto331', 'Jardín', 295.98, 55, 'Proveedor1', '2023-01-23', 'Almacén C')
# (332, 'Artículo332', 'Moda', 100.2, 24, 'Proveedor2', '2023-10-12', 'Almacén B')
# (333, 'Objeto333', 'Deportes', 348.44, 54, 'Proveedor3', '2023-05-24', 'Almacén C')
# (334, 'Objeto334', 'Jardín', 296.69, 6, 'Proveedor1', '2023-11-27', 'Almacén C')
# (335, 'Objeto335', 'Electrónica', 164.38, 96, 'Proveedor3', '2023-10-27', 'Almacén A')
# (336, 'Producto336', 'Electrónica', 449.25, 55, 'Proveedor2', '2023-04-18', 'Almacén C')
# (337, 'Producto337', 'Electrónica', 233.68, 6, 'Proveedor2', '2023-11-01', 'Almacén B')
# (338, 'Objeto338', 'Moda', 298.1, 57, 'Proveedor3', '2023-03-07', 'Almacén A')
# (339, 'Artículo339', 'Jardín', 254.99, 48, 'Proveedor3', '2023-09-15', 'Almacén A')
# (340, 'Artículo340', 'Hogar', 202.88, 56, 'Proveedor2', '2023-12-09', 'Almacén B')
# (341, 'Producto341', 'Deportes', 87.03, 83, 'Proveedor3', '2023-01-21', 'Almacén A')
# (342, 'Artículo342', 'Electrónica', 51.37, 59, 'Proveedor2', '2023-11-23', 'Almacén B')
# (343, 'Objeto343', 'Moda', 214.09, 61, 'Proveedor2', '2023-02-22', 'Almacén A')
# (344, 'Objeto344', 'Electrónica', 442.47, 7, 'Proveedor1', '2023-01-07', 'Almacén C')
# (345, 'Objeto345', 'Hogar', 377.41, 69, 'Proveedor2', '2023-06-25', 'Almacén A')
# (346, 'Producto346', 'Hogar', 489.37, 38, 'Proveedor1', '2023-03-27', 'Almacén B')
# (347, 'Producto347', 'Moda', 58.17, 89, 'Proveedor1', '2023-07-25', 'Almacén C')
# (348, 'Objeto348', 'Hogar', 337.54, 41, 'Proveedor2', '2023-11-25', 'Almacén B')
# (349, 'Artículo349', 'Moda', 63.53, 50, 'Proveedor3', '2023-06-22', 'Almacén B')
# (350, 'Artículo350', 'Electrónica', 459.57, 26, 'Proveedor3', '2023-02-05', 'Almacén C')
# (351, 'Producto351', 'Jardín', 116.74, 92, 'Proveedor3', '2023-12-15', 'Almacén A')
# (352, 'Producto352', 'Moda', 139.53, 68, 'Proveedor3', '2023-11-20', 'Almacén A')
# (353, 'Objeto353', 'Jardín', 178.21, 76, 'Proveedor3', '2023-03-13', 'Almacén B')
# (354, 'Producto354', 'Deportes', 263.24, 71, 'Proveedor1', '2023-11-15', 'Almacén B')
# (355, 'Producto355', 'Moda', 198.42, 37, 'Proveedor1', '2023-02-19', 'Almacén B')
# (356, 'Artículo356', 'Hogar', 452.74, 59, 'Proveedor3', '2023-07-20', 'Almacén A')
# (357, 'Producto357', 'Moda', 466.9, 75, 'Proveedor2', '2023-06-09', 'Almacén B')
# (358, 'Artículo358', 'Jardín', 371.14, 62, 'Proveedor3', '2023-05-18', 'Almacén A')
# (359, 'Producto359', 'Electrónica', 279.4, 32, 'Proveedor2', '2023-05-04', 'Almacén A')
# (360, 'Artículo360', 'Moda', 382.54, 39, 'Proveedor1', '2023-08-09', 'Almacén B')
# (361, 'Artículo361', 'Moda', 392.97, 32, 'Proveedor2', '2023-04-03', 'Almacén B')
# (362, 'Producto362', 'Moda', 228.06, 4, 'Proveedor2', '2023-10-18', 'Almacén C')
# (363, 'Producto363', 'Jardín', 152.05, 34, 'Proveedor1', '2023-11-27', 'Almacén C')
# (364, 'Artículo364', 'Jardín', 80.49, 67, 'Proveedor3', '2023-09-25', 'Almacén B')
# (365, 'Producto365', 'Jardín', 10.28, 6, 'Proveedor2', '2023-12-17', 'Almacén B')
# (366, 'Producto366', 'Jardín', 457.13, 29, 'Proveedor1', '2023-11-18', 'Almacén C')
# (367, 'Producto367', 'Moda', 332.28, 6, 'Proveedor2', '2023-12-17', 'Almacén A')
# (368, 'Objeto368', 'Deportes', 11.29, 43, 'Proveedor1', '2023-07-18', 'Almacén B')
# (369, 'Objeto369', 'Electrónica', 439.46, 29, 'Proveedor2', '2023-11-28', 'Almacén A')
# (370, 'Objeto370', 'Jardín', 33.05, 41, 'Proveedor2', '2023-12-05', 'Almacén C')
# (371, 'Objeto371', 'Hogar', 161.9, 80, 'Proveedor3', '2023-07-13', 'Almacén A')
# (372, 'Producto372', 'Moda', 99.71, 66, 'Proveedor3', '2023-02-26', 'Almacén C')
# (373, 'Artículo373', 'Hogar', 10, 56, 'Proveedor1', '2023-04-16', 'Almacén A')
# (374, 'Producto374', 'Hogar', 410.1, 21, 'Proveedor2', '2023-01-20', 'Almacén A')
# (375, 'Objeto375', 'Deportes', 453.4, 85, 'Proveedor2', '2023-08-16', 'Almacén A')
# (376, 'Producto376', 'Deportes', 336.74, 47, 'Proveedor3', '2023-04-28', 'Almacén B')
# (377, 'Producto377', 'Hogar', 446.78, 71, 'Proveedor2', '2023-11-04', 'Almacén C')
# (378, 'Objeto378', 'Deportes', 349.88, 2, 'Proveedor1', '2023-06-18', 'Almacén B')
# (379, 'Artículo379', 'Moda', 11.84, 97, 'Proveedor2', '2023-03-16', 'Almacén B')
# (380, 'Objeto380', 'Jardín', 368.88, 59, 'Proveedor3', '2023-11-10', 'Almacén B')
# (381, 'Objeto381', 'Jardín', 311.64, 65, 'Proveedor1', '2023-03-23', 'Almacén B')
# (382, 'Artículo382', 'Moda', 480.98, 18, 'Proveedor3', '2023-11-15', 'Almacén B')
# (383, 'Artículo383', 'Hogar', 144.19, 89, 'Proveedor3', '2023-07-02', 'Almacén C')
# (384, 'Producto384', 'Electrónica', 422.73, 18, 'Proveedor1', '2023-12-25', 'Almacén C')
# (385, 'Artículo385', 'Hogar', 53.92, 93, 'Proveedor1', '2023-12-28', 'Almacén A')
# (386, 'Producto386', 'Deportes', 398.95, 91, 'Proveedor1', '2023-05-04', 'Almacén C')
# (387, 'Objeto387', 'Jardín', 425.34, 75, 'Proveedor3', '2023-06-19', 'Almacén C')
# (388, 'Objeto388', 'Deportes', 73.94, 39, 'Proveedor2', '2023-05-22', 'Almacén B')
# (389, 'Objeto389', 'Hogar', 252.09, 15, 'Proveedor2', '2023-11-11', 'Almacén C')
# (390, 'Objeto390', 'Jardín', 400.25, 14, 'Proveedor1', '2023-05-01', 'Almacén A')
# (391, 'Artículo391', 'Hogar', 476.96, 58, 'Proveedor1', '2023-05-26', 'Almacén B')
# (392, 'Artículo392', 'Electrónica', 32.76, 98, 'Proveedor2', '2023-12-14', 'Almacén B')
# (393, 'Producto393', 'Electrónica', 189.69, 76, 'Proveedor1', '2023-07-01', 'Almacén C')
# (394, 'Producto394', 'Hogar', 176.31, 3, 'Proveedor2', '2023-01-10', 'Almacén B')
# (395, 'Producto395', 'Jardín', 258.06, 3, 'Proveedor1', '2023-06-28', 'Almacén C')
# (396, 'Producto396', 'Jardín', 469.97, 3, 'Proveedor3', '2023-09-04', 'Almacén A')
# (397, 'Objeto397', 'Electrónica', 107.82, 58, 'Proveedor2', '2023-08-01', 'Almacén A')
# (398, 'Producto398', 'Electrónica', 335.76, 61, 'Proveedor2', '2023-06-06', 'Almacén C')
# (399, 'Objeto399', 'Moda', 245.78, 26, 'Proveedor3', '2023-07-03', 'Almacén B')
# (400, 'Objeto400', 'Moda', 420.73, 41, 'Proveedor1', '2023-04-22', 'Almacén B')
# (401, 'Artículo401', 'Moda', 361.13, 24, 'Proveedor2', '2023-02-15', 'Almacén B')
# (402, 'Objeto402', 'Jardín', 59.18, 84, 'Proveedor1', '2023-12-25', 'Almacén B')
# (403, 'Producto403', 'Deportes', 365.4, 50, 'Proveedor1', '2023-09-02', 'Almacén B')
# (404, 'Producto404', 'Moda', 409.54, 39, 'Proveedor1', '2023-04-11', 'Almacén C')
# (405, 'Objeto405', 'Deportes', 254.54, 56, 'Proveedor2', '2023-02-18', 'Almacén A')
# (406, 'Producto406', 'Hogar', 93.37, 99, 'Proveedor3', '2023-06-08', 'Almacén C')
# (407, 'Producto407', 'Jardín', 218.95, 87, 'Proveedor3', '2023-04-25', 'Almacén C')
# (408, 'Objeto408', 'Jardín', 98.17, 84, 'Proveedor2', '2023-10-20', 'Almacén B')
# (409, 'Producto409', 'Jardín', 72.94, 93, 'Proveedor1', '2023-11-19', 'Almacén B')
# (410, 'Objeto410', 'Moda', 316.66, 70, 'Proveedor2', '2023-10-07', 'Almacén C')
# (411, 'Producto411', 'Jardín', 366.43, 33, 'Proveedor3', '2023-04-04', 'Almacén A')
# (412, 'Producto412', 'Jardín', 148.98, 69, 'Proveedor2', '2023-05-14', 'Almacén B')
# (413, 'Producto413', 'Moda', 415.68, 74, 'Proveedor3', '2023-11-13', 'Almacén B')
# (414, 'Objeto414', 'Electrónica', 124.87, 67, 'Proveedor2', '2023-04-05', 'Almacén B')
# (415, 'Objeto415', 'Deportes', 260.83, 37, 'Proveedor2', '2023-10-19', 'Almacén B')
# (416, 'Artículo416', 'Moda', 281.17, 69, 'Proveedor1', '2023-10-17', 'Almacén A')
# (417, 'Artículo417', 'Jardín', 361.71, 37, 'Proveedor2', '2023-11-14', 'Almacén C')
# (418, 'Artículo418', 'Moda', 81.38, 42, 'Proveedor2', '2023-06-17', 'Almacén B')
# (419, 'Objeto419', 'Jardín', 29.83, 12, 'Proveedor2', '2023-09-20', 'Almacén B')
# (420, 'Producto420', 'Hogar', 58.07, 44, 'Proveedor2', '2023-04-23', 'Almacén C')
# (421, 'Artículo421', 'Hogar', 98.17, 75, 'Proveedor2', '2023-12-27', 'Almacén A')
# (422, 'Producto422', 'Moda', 141.82, 73, 'Proveedor3', '2023-01-25', 'Almacén A')
# (423, 'Objeto423', 'Hogar', 486.93, 71, 'Proveedor2', '2023-04-28', 'Almacén B')
# (424, 'Objeto424', 'Deportes', 435.76, 5, 'Proveedor3', '2023-12-25', 'Almacén A')
# (425, 'Artículo425', 'Electrónica', 103.8, 1, 'Proveedor2', '2023-09-18', 'Almacén B')
# (426, 'Objeto426', 'Jardín', 342.68, 53, 'Proveedor2', '2023-11-20', 'Almacén A')
# (427, 'Producto427', 'Moda', 45.83, 100, 'Proveedor1', '2023-10-09', 'Almacén C')
# (428, 'Artículo428', 'Electrónica', 86.45, 18, 'Proveedor3', '2023-09-25', 'Almacén A')
# (429, 'Producto429', 'Hogar', 131.87, 93, 'Proveedor3', '2023-10-09', 'Almacén C')
# (430, 'Artículo430', 'Deportes', 153.37, 7, 'Proveedor2', '2023-12-21', 'Almacén B')
# (431, 'Objeto431', 'Jardín', 445, 7, 'Proveedor1', '2023-12-14', 'Almacén A')
# (432, 'Artículo432', 'Electrónica', 468.72, 97, 'Proveedor3', '2023-03-05', 'Almacén A')
# (433, 'Objeto433', 'Hogar', 374.25, 26, 'Proveedor3', '2023-07-21', 'Almacén A')
# (434, 'Objeto434', 'Deportes', 459.84, 61, 'Proveedor3', '2023-03-26', 'Almacén B')
# (435, 'Producto435', 'Electrónica', 401.05, 34, 'Proveedor2', '2023-05-15', 'Almacén C')
# (436, 'Producto436', 'Deportes', 226.72, 14, 'Proveedor1', '2023-03-21', 'Almacén A')
# (437, 'Producto437', 'Hogar', 492.35, 72, 'Proveedor2', '2023-12-11', 'Almacén A')
# (438, 'Objeto438', 'Hogar', 151.9, 50, 'Proveedor3', '2023-06-01', 'Almacén B')
# (439, 'Objeto439', 'Jardín', 229.87, 97, 'Proveedor3', '2023-06-24', 'Almacén B')
# (440, 'Producto440', 'Electrónica', 270, 87, 'Proveedor3', '2023-12-13', 'Almacén B')
# (441, 'Artículo441', 'Jardín', 29.56, 25, 'Proveedor3', '2023-05-13', 'Almacén A')
# (442, 'Objeto442', 'Deportes', 328.26, 10, 'Proveedor3', '2023-10-21', 'Almacén C')
# (443, 'Producto443', 'Jardín', 483.61, 82, 'Proveedor3', '2023-07-15', 'Almacén A')
# (444, 'Objeto444', 'Hogar', 416.78, 44, 'Proveedor3', '2023-10-27', 'Almacén A')
# (445, 'Producto445', 'Hogar', 440.02, 32, 'Proveedor3', '2023-03-28', 'Almacén B')
# (446, 'Artículo446', 'Electrónica', 475.88, 53, 'Proveedor2', '2023-03-26', 'Almacén B')
# (447, 'Artículo447', 'Hogar', 289.39, 55, 'Proveedor2', '2023-11-12', 'Almacén B')
# (448, 'Artículo448', 'Electrónica', 423.34, 91, 'Proveedor2', '2023-09-03', 'Almacén C')
# (449, 'Producto449', 'Jardín', 27.03, 10, 'Proveedor1', '2023-07-15', 'Almacén B')
# (450, 'Artículo450', 'Deportes', 116.3, 30, 'Proveedor3', '2023-03-15', 'Almacén B')
# (451, 'Producto451', 'Electrónica', 488.47, 34, 'Proveedor3', '2023-03-21', 'Almacén B')
# (452, 'Objeto452', 'Hogar', 493.3, 21, 'Proveedor2', '2023-08-14', 'Almacén B')
# (453, 'Producto453', 'Electrónica', 319.49, 10, 'Proveedor1', '2023-01-03', 'Almacén C')
# (454, 'Objeto454', 'Moda', 341.08, 29, 'Proveedor3', '2023-07-14', 'Almacén C')
# (455, 'Artículo455', 'Deportes', 186.59, 75, 'Proveedor2', '2023-04-28', 'Almacén C')
# (456, 'Artículo456', 'Electrónica', 213.26, 5, 'Proveedor1', '2023-07-02', 'Almacén B')
# (457, 'Artículo457', 'Electrónica', 259.02, 54, 'Proveedor3', '2023-01-17', 'Almacén C')
# (458, 'Artículo458', 'Deportes', 431.21, 71, 'Proveedor3', '2023-09-09', 'Almacén B')
# (459, 'Producto459', 'Deportes', 63.77, 57, 'Proveedor1', '2023-10-21', 'Almacén A')
# (460, 'Artículo460', 'Deportes', 475.32, 2, 'Proveedor2', '2023-12-03', 'Almacén A')
# (461, 'Objeto461', 'Hogar', 331.66, 88, 'Proveedor3', '2023-10-14', 'Almacén B')
# (462, 'Producto462', 'Electrónica', 257.27, 25, 'Proveedor1', '2023-04-06', 'Almacén C')
# (463, 'Artículo463', 'Jardín', 294.11, 95, 'Proveedor2', '2023-01-13', 'Almacén B')
# (464, 'Objeto464', 'Electrónica', 221.86, 9, 'Proveedor1', '2023-05-22', 'Almacén A')
# (465, 'Objeto465', 'Moda', 28.81, 37, 'Proveedor1', '2023-05-28', 'Almacén B')
# (466, 'Objeto466', 'Moda', 497.44, 3, 'Proveedor2', '2023-12-12', 'Almacén C')
# (467, 'Artículo467', 'Hogar', 137.74, 10, 'Proveedor2', '2023-10-23', 'Almacén C')
# (468, 'Objeto468', 'Moda', 367.29, 86, 'Proveedor2', '2023-11-04', 'Almacén A')
# (469, 'Objeto469', 'Hogar', 129.37, 55, 'Proveedor1', '2023-05-28', 'Almacén A')
# (470, 'Producto470', 'Hogar', 320.94, 78, 'Proveedor1', '2023-08-08', 'Almacén B')
# (471, 'Producto471', 'Jardín', 218.3, 98, 'Proveedor3', '2023-03-14', 'Almacén C')
# (472, 'Artículo472', 'Deportes', 497, 53, 'Proveedor1', '2023-03-07', 'Almacén A')
# (473, 'Producto473', 'Moda', 65.16, 8, 'Proveedor2', '2023-11-22', 'Almacén A')
# (474, 'Objeto474', 'Jardín', 79.33, 49, 'Proveedor2', '2023-04-13', 'Almacén A')
# (475, 'Artículo475', 'Deportes', 470.17, 40, 'Proveedor2', '2023-08-02', 'Almacén C')
# (476, 'Producto476', 'Hogar', 250.53, 60, 'Proveedor2', '2023-12-20', 'Almacén A')
# (477, 'Producto477', 'Jardín', 423.74, 19, 'Proveedor3', '2023-06-14', 'Almacén C')
# (478, 'Artículo478', 'Moda', 395.81, 97, 'Proveedor2', '2023-12-03', 'Almacén C')
# (479, 'Artículo479', 'Electrónica', 222.95, 42, 'Proveedor1', '2023-04-08', 'Almacén B')
# (480, 'Artículo480', 'Jardín', 160.84, 85, 'Proveedor1', '2023-07-21', 'Almacén B')
# (481, 'Artículo481', 'Hogar', 214.39, 62, 'Proveedor2', '2023-07-13', 'Almacén B')
# (482, 'Objeto482', 'Moda', 119.88, 7, 'Proveedor2', '2023-12-26', 'Almacén A')
# (483, 'Artículo483', 'Electrónica', 165.68, 91, 'Proveedor1', '2023-10-14', 'Almacén C')
# (484, 'Artículo484', 'Moda', 80.2, 90, 'Proveedor2', '2023-11-22', 'Almacén A')
# (485, 'Artículo485', 'Electrónica', 162.98, 14, 'Proveedor2', '2023-08-09', 'Almacén B')
# (486, 'Producto486', 'Moda', 81.07, 65, 'Proveedor1', '2023-12-24', 'Almacén A')
# (487, 'Objeto487', 'Hogar', 268.6, 8, 'Proveedor2', '2023-11-16', 'Almacén C')
# (488, 'Producto488', 'Electrónica', 284.85, 99, 'Proveedor1', '2023-03-10', 'Almacén C')
# (489, 'Producto489', 'Moda', 226.95, 93, 'Proveedor1', '2023-02-17', 'Almacén A')
# (490, 'Objeto490', 'Moda', 135.39, 56, 'Proveedor3', '2023-04-20', 'Almacén A')
# (491, 'Producto491', 'Jardín', 488.46, 8, 'Proveedor3', '2023-10-06', 'Almacén C')
# (492, 'Objeto492', 'Deportes', 433.7, 74, 'Proveedor2', '2023-01-19', 'Almacén C')
# (493, 'Objeto493', 'Jardín', 242.95, 14, 'Proveedor1', '2023-09-27', 'Almacén B')
# (494, 'Artículo494', 'Hogar', 151.03, 29, 'Proveedor3', '2023-06-01', 'Almacén B')
# (495, 'Objeto495', 'Moda', 219.57, 72, 'Proveedor2', '2023-12-09', 'Almacén B')
# (496, 'Objeto496', 'Deportes', 410.39, 63, 'Proveedor1', '2023-06-06', 'Almacén C')
# (497, 'Objeto497', 'Jardín', 371.33, 10, 'Proveedor3', '2023-09-02', 'Almacén A')
# (498, 'Objeto498', 'Hogar', 54.77, 72, 'Proveedor1', '2023-08-18', 'Almacén C')
# (499, 'Objeto499', 'Deportes', 130.73, 14, 'Proveedor3', '2023-01-08', 'Almacén C')
# (500, 'Producto500', 'Hogar', 165.88, 94, 'Proveedor1', '2023-02-08', 'Almacén B')
# (501, 'Objeto501', 'Moda', 206.56, 87, 'Proveedor2', '2023-09-10', 'Almacén C')
# (502, 'Producto502', 'Deportes', 324.96, 1, 'Proveedor1', '2023-04-26', 'Almacén B')
# (503, 'Artículo503', 'Hogar', 377.67, 39, 'Proveedor2', '2023-05-02', 'Almacén B')
# (504, 'Producto504', 'Moda', 489.5, 13, 'Proveedor3', '2023-07-24', 'Almacén C')
# (505, 'Producto505', 'Hogar', 89.41, 22, 'Proveedor2', '2023-03-26', 'Almacén B')
# (506, 'Producto506', 'Deportes', 127.75, 85, 'Proveedor2', '2023-09-01', 'Almacén C')
# (507, 'Objeto507', 'Hogar', 404.34, 17, 'Proveedor2', '2023-05-17', 'Almacén C')
# (508, 'Producto508', 'Electrónica', 457.72, 43, 'Proveedor1', '2023-08-01', 'Almacén B')
# (509, 'Artículo509', 'Moda', 425.27, 100, 'Proveedor2', '2023-07-18', 'Almacén B')
# (510, 'Producto510', 'Moda', 369.46, 39, 'Proveedor3', '2023-07-27', 'Almacén A')
# (511, 'Producto511', 'Deportes', 488.09, 88, 'Proveedor3', '2023-08-14', 'Almacén C')
# (512, 'Artículo512', 'Electrónica', 14.58, 87, 'Proveedor2', '2023-01-24', 'Almacén C')
# (513, 'Producto513', 'Moda', 116.15, 89, 'Proveedor3', '2023-04-18', 'Almacén B')
# (514, 'Artículo514', 'Moda', 484.24, 45, 'Proveedor2', '2023-04-24', 'Almacén A')
# (515, 'Artículo515', 'Hogar', 358.88, 58, 'Proveedor1', '2023-12-11', 'Almacén A')
# (516, 'Objeto516', 'Hogar', 319.68, 50, 'Proveedor2', '2023-02-02', 'Almacén C')
# (517, 'Objeto517', 'Jardín', 159.83, 55, 'Proveedor1', '2023-05-11', 'Almacén A')
# (518, 'Artículo518', 'Deportes', 132.46, 57, 'Proveedor3', '2023-04-16', 'Almacén B')
# (519, 'Producto519', 'Deportes', 462.57, 79, 'Proveedor2', '2023-05-14', 'Almacén B')
# (520, 'Artículo520', 'Hogar', 399.97, 22, 'Proveedor1', '2023-11-25', 'Almacén B')
# (521, 'Artículo521', 'Electrónica', 337.79, 54, 'Proveedor2', '2023-05-25', 'Almacén B')
# (522, 'Objeto522', 'Deportes', 112.21, 45, 'Proveedor3', '2023-09-11', 'Almacén B')
# (523, 'Objeto523', 'Moda', 391.77, 20, 'Proveedor2', '2023-10-20', 'Almacén A')
# (524, 'Artículo524', 'Deportes', 392.55, 76, 'Proveedor1', '2023-11-02', 'Almacén C')
# (525, 'Objeto525', 'Deportes', 275.07, 75, 'Proveedor1', '2023-11-04', 'Almacén C')
# (526, 'Objeto526', 'Hogar', 321.1, 8, 'Proveedor3', '2023-06-12', 'Almacén B')
# (527, 'Objeto527', 'Deportes', 205.72, 65, 'Proveedor1', '2023-10-13', 'Almacén A')
# (528, 'Objeto528', 'Jardín', 473.19, 96, 'Proveedor1', '2023-05-02', 'Almacén C')
# (529, 'Artículo529', 'Deportes', 463.14, 2, 'Proveedor1', '2023-06-07', 'Almacén C')
# (530, 'Objeto530', 'Hogar', 262.24, 77, 'Proveedor2', '2023-09-21', 'Almacén A')
# (531, 'Objeto531', 'Electrónica', 286.18, 99, 'Proveedor1', '2023-07-04', 'Almacén C')
# (532, 'Objeto532', 'Deportes', 434.52, 53, 'Proveedor3', '2023-11-22', 'Almacén C')
# (533, 'Producto533', 'Hogar', 357.47, 12, 'Proveedor1', '2023-03-06', 'Almacén A')
# (534, 'Artículo534', 'Deportes', 38.67, 97, 'Proveedor3', '2023-10-04', 'Almacén A')
# (535, 'Objeto535', 'Hogar', 326.26, 70, 'Proveedor1', '2023-06-01', 'Almacén B')
# (536, 'Producto536', 'Moda', 91.96, 81, 'Proveedor2', '2023-08-20', 'Almacén A')
# (537, 'Producto537', 'Jardín', 259.97, 58, 'Proveedor2', '2023-03-02', 'Almacén B')
# (538, 'Producto538', 'Moda', 85.91, 34, 'Proveedor2', '2023-03-24', 'Almacén B')
# (539, 'Producto539', 'Moda', 12.18, 30, 'Proveedor2', '2023-05-21', 'Almacén A')
# (540, 'Objeto540', 'Hogar', 379.97, 6, 'Proveedor2', '2023-02-10', 'Almacén C')
# (541, 'Objeto541', 'Moda', 66.3, 36, 'Proveedor3', '2023-10-28', 'Almacén B')
# (542, 'Artículo542', 'Deportes', 122.29, 83, 'Proveedor3', '2023-06-16', 'Almacén A')
# (543, 'Objeto543', 'Deportes', 69.93, 38, 'Proveedor1', '2023-11-03', 'Almacén C')
# (544, 'Artículo544', 'Moda', 204.71, 30, 'Proveedor3', '2023-04-12', 'Almacén C')
# (545, 'Artículo545', 'Moda', 304.95, 46, 'Proveedor1', '2023-10-25', 'Almacén C')
# (546, 'Producto546', 'Electrónica', 79.25, 62, 'Proveedor2', '2023-11-27', 'Almacén A')
# (547, 'Producto547', 'Moda', 327.07, 60, 'Proveedor3', '2023-03-08', 'Almacén B')
# (548, 'Artículo548', 'Moda', 477.39, 84, 'Proveedor1', '2023-12-08', 'Almacén A')
# (549, 'Producto549', 'Deportes', 42.39, 47, 'Proveedor2', '2023-03-07', 'Almacén C')
# (550, 'Producto550', 'Moda', 194.98, 37, 'Proveedor1', '2023-07-14', 'Almacén B')
# (551, 'Artículo551', 'Moda', 451.04, 44, 'Proveedor3', '2023-02-25', 'Almacén B')
# (552, 'Producto552', 'Electrónica', 453.1, 40, 'Proveedor3', '2023-05-21', 'Almacén C')
# (553, 'Artículo553', 'Deportes', 196.49, 82, 'Proveedor2', '2023-08-04', 'Almacén C')
# (554, 'Artículo554', 'Jardín', 290.32, 58, 'Proveedor1', '2023-09-24', 'Almacén B')
# (555, 'Producto555', 'Electrónica', 424.76, 94, 'Proveedor3', '2023-05-22', 'Almacén B')
# (556, 'Objeto556', 'Hogar', 314.97, 53, 'Proveedor2', '2023-07-23', 'Almacén A')
# (557, 'Producto557', 'Deportes', 305.32, 34, 'Proveedor3', '2023-09-19', 'Almacén B')
# (558, 'Producto558', 'Jardín', 11.53, 38, 'Proveedor3', '2023-02-10', 'Almacén B')
# (559, 'Objeto559', 'Deportes', 369.75, 93, 'Proveedor1', '2023-10-19', 'Almacén B')
# (560, 'Producto560', 'Hogar', 200.05, 45, 'Proveedor3', '2023-02-24', 'Almacén A')
# (561, 'Producto561', 'Jardín', 436.8, 69, 'Proveedor1', '2023-09-25', 'Almacén B')
# (562, 'Artículo562', 'Moda', 128.95, 66, 'Proveedor3', '2023-05-08', 'Almacén B')
# (563, 'Artículo563', 'Jardín', 132.21, 61, 'Proveedor3', '2023-11-08', 'Almacén A')
# (564, 'Producto564', 'Hogar', 396.96, 30, 'Proveedor3', '2023-04-15', 'Almacén A')
# (565, 'Objeto565', 'Hogar', 208.99, 94, 'Proveedor3', '2023-02-26', 'Almacén C')
# (566, 'Objeto566', 'Jardín', 265.3, 9, 'Proveedor2', '2023-12-03', 'Almacén A')
# (567, 'Artículo567', 'Electrónica', 114.76, 20, 'Proveedor1', '2023-12-28', 'Almacén B')
# (568, 'Producto568', 'Electrónica', 92.64, 45, 'Proveedor2', '2023-01-20', 'Almacén B')
# (569, 'Artículo569', 'Deportes', 476.84, 4, 'Proveedor2', '2023-11-03', 'Almacén B')
# (570, 'Artículo570', 'Jardín', 313.75, 42, 'Proveedor3', '2023-08-20', 'Almacén C')
# (571, 'Artículo571', 'Electrónica', 171.47, 5, 'Proveedor3', '2023-06-23', 'Almacén C')
# (572, 'Objeto572', 'Electrónica', 357.43, 7, 'Proveedor3', '2023-05-27', 'Almacén B')
# (573, 'Artículo573', 'Jardín', 248.78, 66, 'Proveedor3', '2023-10-10', 'Almacén B')
# (574, 'Artículo574', 'Jardín', 468.78, 16, 'Proveedor3', '2023-05-10', 'Almacén B')
# (575, 'Objeto575', 'Jardín', 451.35, 26, 'Proveedor1', '2023-01-06', 'Almacén A')
# (576, 'Objeto576', 'Moda', 63.61, 37, 'Proveedor2', '2023-12-14', 'Almacén C')
# (577, 'Artículo577', 'Moda', 481.54, 91, 'Proveedor2', '2023-02-19', 'Almacén C')
# ...
# (9814, 'Producto9814', 'Jardín', 18.4, 81, 'Proveedor1', '2023-06-13', 'Almacén C')
# (9815, 'Objeto9815', 'Hogar', 143.46, 92, 'Proveedor1', '2023-06-25', 'Almacén C')
# (9816, 'Artículo9816', 'Electrónica', 163.48, 56, 'Proveedor2', '2023-10-07', 'Almacén B')
# (9817, 'Objeto9817', 'Deportes', 259.25, 50, 'Proveedor2', '2023-05-13', 'Almacén C')
# (9818, 'Objeto9818', 'Hogar', 318.8, 67, 'Proveedor2', '2023-12-03', 'Almacén C')
# (9819, 'Objeto9819', 'Electrónica', 122.59, 49, 'Proveedor1', '2023-04-17', 'Almacén A')
# (9820, 'Producto9820', 'Jardín', 228.33, 73, 'Proveedor3', '2023-12-17', 'Almacén B')
# (9821, 'Producto9821', 'Hogar', 426.43, 57, 'Proveedor1', '2023-02-26', 'Almacén C')
# (9822, 'Artículo9822', 'Moda', 181.34, 57, 'Proveedor1', '2023-07-01', 'Almacén C')
# (9823, 'Artículo9823', 'Hogar', 358.11, 78, 'Proveedor1', '2023-08-06', 'Almacén B')
# (9824, 'Artículo9824', 'Electrónica', 175.96, 86, 'Proveedor2', '2023-06-13', 'Almacén C')
# (9825, 'Artículo9825', 'Hogar', 285.68, 84, 'Proveedor3', '2023-12-10', 'Almacén A')
# (9826, 'Objeto9826', 'Jardín', 220.79, 52, 'Proveedor2', '2023-12-05', 'Almacén C')
# (9827, 'Objeto9827', 'Moda', 356.06, 28, 'Proveedor1', '2023-07-24', 'Almacén B')
# (9828, 'Objeto9828', 'Electrónica', 399.05, 1, 'Proveedor3', '2023-02-14', 'Almacén A')
# (9829, 'Producto9829', 'Electrónica', 85.68, 21, 'Proveedor2', '2023-11-08', 'Almacén C')
# (9830, 'Producto9830', 'Electrónica', 370.54, 39, 'Proveedor2', '2023-11-19', 'Almacén C')
# (9831, 'Objeto9831', 'Jardín', 486.46, 46, 'Proveedor3', '2023-08-09', 'Almacén A')
# (9832, 'Producto9832', 'Jardín', 266.17, 69, 'Proveedor2', '2023-01-13', 'Almacén A')
# (9833, 'Objeto9833', 'Deportes', 186.7, 62, 'Proveedor1', '2023-12-19', 'Almacén A')
# (9834, 'Objeto9834', 'Jardín', 471.22, 14, 'Proveedor3', '2023-07-25', 'Almacén A')
# (9835, 'Objeto9835', 'Hogar', 246.07, 66, 'Proveedor2', '2023-09-24', 'Almacén C')
# (9836, 'Artículo9836', 'Hogar', 240.38, 4, 'Proveedor3', '2023-10-16', 'Almacén B')
# (9837, 'Objeto9837', 'Jardín', 438.33, 19, 'Proveedor3', '2023-12-21', 'Almacén B')
# (9838, 'Objeto9838', 'Moda', 184.2, 42, 'Proveedor3', '2023-02-04', 'Almacén C')
# (9839, 'Producto9839', 'Hogar', 365.6, 7, 'Proveedor3', '2023-07-19', 'Almacén B')
# (9840, 'Objeto9840', 'Moda', 431.99, 7, 'Proveedor3', '2023-02-17', 'Almacén C')
# (9841, 'Objeto9841', 'Moda', 156.06, 46, 'Proveedor3', '2023-11-14', 'Almacén A')
# (9842, 'Objeto9842', 'Jardín', 12.19, 18, 'Proveedor1', '2023-02-09', 'Almacén B')
# (9843, 'Artículo9843', 'Deportes', 406.28, 87, 'Proveedor1', '2023-10-01', 'Almacén A')
# (9844, 'Artículo9844', 'Electrónica', 74.35, 82, 'Proveedor3', '2023-08-27', 'Almacén A')
# (9845, 'Producto9845', 'Deportes', 307.33, 67, 'Proveedor1', '2023-02-07', 'Almacén C')
# (9846, 'Artículo9846', 'Electrónica', 29, 22, 'Proveedor2', '2023-05-17', 'Almacén B')
# (9847, 'Objeto9847', 'Deportes', 306.27, 89, 'Proveedor2', '2023-12-02', 'Almacén B')
# (9848, 'Objeto9848', 'Moda', 446.71, 83, 'Proveedor3', '2023-08-25', 'Almacén C')
# (9849, 'Producto9849', 'Electrónica', 134.44, 7, 'Proveedor1', '2023-09-07', 'Almacén B')
# (9850, 'Producto9850', 'Hogar', 76.99, 43, 'Proveedor1', '2023-05-16', 'Almacén B')
# (9851, 'Artículo9851', 'Jardín', 391.06, 13, 'Proveedor3', '2023-09-21', 'Almacén B')
# (9852, 'Artículo9852', 'Hogar', 25.29, 39, 'Proveedor3', '2023-02-19', 'Almacén C')
# (9853, 'Producto9853', 'Deportes', 385.45, 4, 'Proveedor3', '2023-12-22', 'Almacén B')
# (9854, 'Objeto9854', 'Electrónica', 292.12, 72, 'Proveedor3', '2023-08-09', 'Almacén A')
# (9855, 'Objeto9855', 'Jardín', 465.1, 27, 'Proveedor1', '2023-10-05', 'Almacén C')
# (9856, 'Artículo9856', 'Jardín', 494.83, 37, 'Proveedor1', '2023-07-02', 'Almacén B')
# (9857, 'Objeto9857', 'Hogar', 266.08, 12, 'Proveedor3', '2023-08-26', 'Almacén C')
# (9858, 'Objeto9858', 'Moda', 484.36, 12, 'Proveedor2', '2023-12-24', 'Almacén C')
# (9859, 'Objeto9859', 'Electrónica', 346.88, 52, 'Proveedor2', '2023-08-27', 'Almacén C')
# (9860, 'Producto9860', 'Electrónica', 417.65, 83, 'Proveedor1', '2023-11-07', 'Almacén C')
# (9861, 'Artículo9861', 'Moda', 427.33, 44, 'Proveedor1', '2023-03-19', 'Almacén B')
# (9862, 'Objeto9862', 'Electrónica', 345.26, 70, 'Proveedor1', '2023-11-23', 'Almacén B')
# (9863, 'Artículo9863', 'Moda', 402.85, 48, 'Proveedor2', '2023-05-20', 'Almacén C')
# (9864, 'Producto9864', 'Moda', 196.87, 42, 'Proveedor2', '2023-02-17', 'Almacén A')
# (9865, 'Producto9865', 'Electrónica', 487.21, 63, 'Proveedor2', '2023-12-27', 'Almacén C')
# (9866, 'Objeto9866', 'Hogar', 206.97, 28, 'Proveedor2', '2023-12-20', 'Almacén B')
# (9867, 'Producto9867', 'Jardín', 397.96, 92, 'Proveedor3', '2023-03-04', 'Almacén B')
# (9868, 'Objeto9868', 'Moda', 213.65, 5, 'Proveedor2', '2023-12-17', 'Almacén B')
# (9869, 'Artículo9869', 'Moda', 67.38, 92, 'Proveedor1', '2023-11-05', 'Almacén A')
# (9870, 'Artículo9870', 'Electrónica', 478.9, 65, 'Proveedor1', '2023-10-09', 'Almacén C')
# (9871, 'Artículo9871', 'Deportes', 158.13, 7, 'Proveedor1', '2023-09-09', 'Almacén C')
# (9872, 'Producto9872', 'Hogar', 22.85, 53, 'Proveedor3', '2023-02-25', 'Almacén B')
# (9873, 'Objeto9873', 'Deportes', 144.19, 35, 'Proveedor2', '2023-03-06', 'Almacén C')
# (9874, 'Objeto9874', 'Electrónica', 146.71, 40, 'Proveedor3', '2023-05-10', 'Almacén C')
# (9875, 'Producto9875', 'Moda', 320.95, 72, 'Proveedor1', '2023-06-10', 'Almacén B')
# (9876, 'Producto9876', 'Moda', 80.74, 47, 'Proveedor3', '2023-03-11', 'Almacén C')
# (9877, 'Artículo9877', 'Hogar', 342.05, 87, 'Proveedor2', '2023-11-01', 'Almacén B')
# (9878, 'Producto9878', 'Jardín', 345.5, 22, 'Proveedor2', '2023-04-18', 'Almacén B')
# (9879, 'Artículo9879', 'Deportes', 50.7, 13, 'Proveedor3', '2023-10-06', 'Almacén B')
# (9880, 'Objeto9880', 'Electrónica', 256.31, 21, 'Proveedor1', '2023-12-08', 'Almacén B')
# (9881, 'Objeto9881', 'Electrónica', 417.82, 90, 'Proveedor2', '2023-01-27', 'Almacén C')
# (9882, 'Artículo9882', 'Electrónica', 194.33, 48, 'Proveedor3', '2023-11-12', 'Almacén A')
# (9883, 'Artículo9883', 'Hogar', 67.23, 13, 'Proveedor2', '2023-01-09', 'Almacén C')
# (9884, 'Producto9884', 'Moda', 128.12, 68, 'Proveedor1', '2023-12-10', 'Almacén B')
# (9885, 'Objeto9885', 'Deportes', 387.88, 9, 'Proveedor2', '2023-01-24', 'Almacén A')
# (9886, 'Objeto9886', 'Deportes', 32.95, 27, 'Proveedor1', '2023-09-25', 'Almacén B')
# (9887, 'Objeto9887', 'Jardín', 116.47, 1, 'Proveedor1', '2023-09-05', 'Almacén A')
# (9888, 'Artículo9888', 'Electrónica', 64.32, 32, 'Proveedor2', '2023-10-18', 'Almacén B')
# (9889, 'Objeto9889', 'Hogar', 169, 86, 'Proveedor2', '2023-05-10', 'Almacén A')
# (9890, 'Objeto9890', 'Electrónica', 311.44, 53, 'Proveedor3', '2023-04-13', 'Almacén B')
# (9891, 'Artículo9891', 'Moda', 166.93, 84, 'Proveedor3', '2023-04-17', 'Almacén A')
# (9892, 'Producto9892', 'Moda', 385.67, 40, 'Proveedor3', '2023-02-20', 'Almacén A')
# (9893, 'Objeto9893', 'Jardín', 129.04, 92, 'Proveedor3', '2023-01-12', 'Almacén C')
# (9894, 'Producto9894', 'Hogar', 60.26, 95, 'Proveedor3', '2023-11-21', 'Almacén A')
# (9895, 'Producto9895', 'Hogar', 389.12, 78, 'Proveedor3', '2023-07-23', 'Almacén A')
# (9896, 'Artículo9896', 'Deportes', 423.63, 62, 'Proveedor2', '2023-09-11', 'Almacén A')
# (9897, 'Artículo9897', 'Electrónica', 256.48, 67, 'Proveedor2', '2023-10-27', 'Almacén C')
# (9898, 'Artículo9898', 'Deportes', 310.56, 92, 'Proveedor1', '2023-08-25', 'Almacén B')
# (9899, 'Artículo9899', 'Moda', 156.58, 10, 'Proveedor2', '2023-12-27', 'Almacén B')
# (9900, 'Artículo9900', 'Deportes', 387.25, 60, 'Proveedor2', '2023-09-26', 'Almacén C')
# (9901, 'Objeto9901', 'Deportes', 357.49, 11, 'Proveedor3', '2023-05-10', 'Almacén A')
# (9902, 'Objeto9902', 'Electrónica', 338.59, 5, 'Proveedor2', '2023-08-07', 'Almacén B')
# (9903, 'Artículo9903', 'Jardín', 345.86, 2, 'Proveedor3', '2023-09-01', 'Almacén B')
# (9904, 'Artículo9904', 'Hogar', 361.25, 38, 'Proveedor1', '2023-07-13', 'Almacén C')
# (9905, 'Artículo9905', 'Hogar', 161.61, 80, 'Proveedor2', '2023-01-16', 'Almacén B')
# (9906, 'Objeto9906', 'Hogar', 139.9, 22, 'Proveedor1', '2023-11-17', 'Almacén A')
# (9907, 'Producto9907', 'Moda', 68.3, 22, 'Proveedor3', '2023-07-03', 'Almacén A')
# (9908, 'Producto9908', 'Jardín', 410.59, 53, 'Proveedor3', '2023-11-28', 'Almacén A')
# (9909, 'Producto9909', 'Moda', 224.84, 49, 'Proveedor1', '2023-04-21', 'Almacén C')
# (9910, 'Objeto9910', 'Hogar', 470.11, 37, 'Proveedor2', '2023-07-21', 'Almacén B')
# (9911, 'Artículo9911', 'Deportes', 454.42, 64, 'Proveedor3', '2023-03-25', 'Almacén A')
# (9912, 'Artículo9912', 'Hogar', 249.97, 10, 'Proveedor2', '2023-01-10', 'Almacén A')
# (9913, 'Artículo9913', 'Electrónica', 208.45, 35, 'Proveedor3', '2023-03-03', 'Almacén C')
# (9914, 'Objeto9914', 'Moda', 108.29, 47, 'Proveedor3', '2023-05-27', 'Almacén A')
# (9915, 'Objeto9915', 'Electrónica', 274.82, 63, 'Proveedor2', '2023-06-13', 'Almacén B')
# (9916, 'Objeto9916', 'Hogar', 244.58, 8, 'Proveedor3', '2023-08-02', 'Almacén C')
# (9917, 'Producto9917', 'Hogar', 143.09, 47, 'Proveedor2', '2023-02-17', 'Almacén C')
# (9918, 'Objeto9918', 'Electrónica', 311.72, 82, 'Proveedor3', '2023-07-23', 'Almacén A')
# (9919, 'Producto9919', 'Moda', 191.02, 51, 'Proveedor1', '2023-04-25', 'Almacén B')
# (9920, 'Producto9920', 'Hogar', 148.76, 56, 'Proveedor2', '2023-07-16', 'Almacén C')
# (9921, 'Artículo9921', 'Hogar', 486.84, 88, 'Proveedor3', '2023-05-03', 'Almacén C')
# (9922, 'Objeto9922', 'Jardín', 15.06, 91, 'Proveedor2', '2023-12-01', 'Almacén A')
# (9923, 'Artículo9923', 'Moda', 145.57, 46, 'Proveedor3', '2023-08-24', 'Almacén A')
# (9924, 'Producto9924', 'Jardín', 133.28, 91, 'Proveedor3', '2023-09-16', 'Almacén C')
# (9925, 'Producto9925', 'Hogar', 298.09, 4, 'Proveedor1', '2023-11-06', 'Almacén C')
# (9926, 'Objeto9926', 'Hogar', 447.54, 4, 'Proveedor2', '2023-04-06', 'Almacén B')
# (9927, 'Producto9927', 'Jardín', 21.57, 76, 'Proveedor2', '2023-04-21', 'Almacén B')
# (9928, 'Objeto9928', 'Electrónica', 235.85, 44, 'Proveedor3', '2023-08-17', 'Almacén A')
# (9929, 'Artículo9929', 'Hogar', 396.48, 98, 'Proveedor1', '2023-11-10', 'Almacén B')
# (9930, 'Producto9930', 'Deportes', 45.62, 29, 'Proveedor2', '2023-03-24', 'Almacén C')
# (9931, 'Producto9931', 'Hogar', 341.53, 86, 'Proveedor2', '2023-05-19', 'Almacén B')
# (9932, 'Artículo9932', 'Hogar', 406.31, 72, 'Proveedor1', '2023-06-17', 'Almacén A')
# (9933, 'Artículo9933', 'Deportes', 221.83, 36, 'Proveedor1', '2023-02-22', 'Almacén B')
# (9934, 'Producto9934', 'Moda', 213.14, 55, 'Proveedor3', '2023-09-20', 'Almacén A')
# (9935, 'Producto9935', 'Jardín', 477.95, 79, 'Proveedor3', '2023-05-09', 'Almacén C')
# (9936, 'Producto9936', 'Moda', 51.13, 2, 'Proveedor3', '2023-10-28', 'Almacén A')
# (9937, 'Objeto9937', 'Deportes', 207.35, 9, 'Proveedor3', '2023-05-13', 'Almacén B')
# (9938, 'Artículo9938', 'Moda', 323.24, 44, 'Proveedor3', '2023-11-19', 'Almacén A')
# (9939, 'Artículo9939', 'Deportes', 77.76, 42, 'Proveedor3', '2023-05-16', 'Almacén B')
# (9940, 'Objeto9940', 'Hogar', 147.01, 80, 'Proveedor3', '2023-03-11', 'Almacén C')
# (9941, 'Producto9941', 'Jardín', 407.04, 63, 'Proveedor1', '2023-10-06', 'Almacén A')
# (9942, 'Artículo9942', 'Electrónica', 394.59, 46, 'Proveedor3', '2023-06-19', 'Almacén C')
# (9943, 'Objeto9943', 'Deportes', 74.08, 90, 'Proveedor1', '2023-01-22', 'Almacén C')
# (9944, 'Producto9944', 'Electrónica', 210.87, 90, 'Proveedor1', '2023-09-21', 'Almacén C')
# (9945, 'Producto9945', 'Deportes', 401.41, 52, 'Proveedor1', '2023-07-21', 'Almacén C')
# (9946, 'Producto9946', 'Hogar', 128.6, 17, 'Proveedor1', '2023-03-19', 'Almacén C')
# (9947, 'Objeto9947', 'Hogar', 84.4, 64, 'Proveedor3', '2023-10-07', 'Almacén C')
# (9948, 'Artículo9948', 'Jardín', 155.11, 63, 'Proveedor2', '2023-04-14', 'Almacén A')
# (9949, 'Objeto9949', 'Jardín', 312.52, 11, 'Proveedor1', '2023-03-02', 'Almacén B')
# (9950, 'Artículo9950', 'Deportes', 279.45, 48, 'Proveedor1', '2023-04-01', 'Almacén B')
# (9951, 'Producto9951', 'Electrónica', 191.08, 64, 'Proveedor3', '2023-07-01', 'Almacén B')
# (9952, 'Producto9952', 'Moda', 228.34, 24, 'Proveedor3', '2023-11-01', 'Almacén A')
# (9953, 'Objeto9953', 'Jardín', 476.1, 62, 'Proveedor2', '2023-02-09', 'Almacén C')
# (9954, 'Artículo9954', 'Jardín', 153.73, 11, 'Proveedor3', '2023-05-07', 'Almacén B')
# (9955, 'Producto9955', 'Moda', 146.5, 64, 'Proveedor2', '2023-01-06', 'Almacén A')
# (9956, 'Artículo9956', 'Deportes', 260.14, 59, 'Proveedor1', '2023-11-05', 'Almacén B')
# (9957, 'Producto9957', 'Hogar', 275.21, 31, 'Proveedor1', '2023-09-12', 'Almacén B')
# (9958, 'Objeto9958', 'Moda', 127.81, 95, 'Proveedor2', '2023-05-03', 'Almacén B')
# (9959, 'Objeto9959', 'Deportes', 136.65, 72, 'Proveedor3', '2023-05-08', 'Almacén B')
# (9960, 'Producto9960', 'Moda', 256.36, 3, 'Proveedor2', '2023-02-02', 'Almacén C')
# (9961, 'Artículo9961', 'Hogar', 370.88, 8, 'Proveedor2', '2023-02-25', 'Almacén C')
# (9962, 'Producto9962', 'Deportes', 430.13, 89, 'Proveedor1', '2023-02-14', 'Almacén B')
# (9963, 'Objeto9963', 'Hogar', 151.27, 41, 'Proveedor3', '2023-07-01', 'Almacén C')
# (9964, 'Objeto9964', 'Deportes', 52.23, 35, 'Proveedor2', '2023-02-14', 'Almacén C')
# (9965, 'Producto9965', 'Deportes', 157.39, 4, 'Proveedor2', '2023-11-02', 'Almacén A')
# (9966, 'Objeto9966', 'Hogar', 396.86, 71, 'Proveedor3', '2023-03-23', 'Almacén C')
# (9967, 'Artículo9967', 'Jardín', 181.32, 10, 'Proveedor3', '2023-08-21', 'Almacén B')
# (9968, 'Artículo9968', 'Moda', 183.68, 76, 'Proveedor2', '2023-05-10', 'Almacén C')
# (9969, 'Artículo9969', 'Moda', 390.93, 33, 'Proveedor1', '2023-02-17', 'Almacén C')
# (9970, 'Objeto9970', 'Hogar', 11.56, 99, 'Proveedor2', '2023-01-28', 'Almacén A')
# (9971, 'Objeto9971', 'Moda', 471.55, 46, 'Proveedor3', '2023-06-13', 'Almacén A')
# (9972, 'Objeto9972', 'Electrónica', 40.03, 69, 'Proveedor1', '2023-12-19', 'Almacén C')
# (9973, 'Producto9973', 'Electrónica', 65.94, 43, 'Proveedor2', '2023-08-07', 'Almacén A')
# (9974, 'Objeto9974', 'Hogar', 146.39, 59, 'Proveedor1', '2023-08-15', 'Almacén B')
# (9975, 'Artículo9975', 'Deportes', 277.62, 4, 'Proveedor1', '2023-06-02', 'Almacén B')
# (9976, 'Artículo9976', 'Jardín', 135.52, 31, 'Proveedor3', '2023-12-28', 'Almacén B')
# (9977, 'Artículo9977', 'Deportes', 187.22, 26, 'Proveedor2', '2023-10-21', 'Almacén B')
# (9978, 'Producto9978', 'Electrónica', 307.59, 99, 'Proveedor3', '2023-04-03', 'Almacén C')
# (9979, 'Objeto9979', 'Hogar', 379.06, 47, 'Proveedor3', '2023-04-11', 'Almacén B')
# (9980, 'Objeto9980', 'Deportes', 331.18, 24, 'Proveedor1', '2023-12-09', 'Almacén B')
# (9981, 'Objeto9981', 'Jardín', 134.42, 1, 'Proveedor1', '2023-10-17', 'Almacén C')
# (9982, 'Objeto9982', 'Electrónica', 34.69, 18, 'Proveedor2', '2023-10-27', 'Almacén B')
# (9983, 'Objeto9983', 'Moda', 487.55, 94, 'Proveedor1', '2023-08-12', 'Almacén C')
# (9984, 'Artículo9984', 'Deportes', 137.65, 34, 'Proveedor1', '2023-06-14', 'Almacén B')
# (9985, 'Artículo9985', 'Jardín', 265.02, 88, 'Proveedor3', '2023-02-28', 'Almacén A')
# (9986, 'Producto9986', 'Hogar', 29.79, 68, 'Proveedor1', '2023-06-03', 'Almacén A')
# (9987, 'Objeto9987', 'Hogar', 231.06, 21, 'Proveedor3', '2023-09-01', 'Almacén A')
# (9988, 'Artículo9988', 'Moda', 221.91, 64, 'Proveedor3', '2023-03-05', 'Almacén B')
# (9989, 'Objeto9989', 'Deportes', 217.15, 10, 'Proveedor2', '2023-12-17', 'Almacén B')
# (9990, 'Artículo9990', 'Hogar', 92.34, 65, 'Proveedor2', '2023-06-20', 'Almacén C')
# (9991, 'Producto9991', 'Hogar', 390.06, 28, 'Proveedor1', '2023-02-05', 'Almacén C')
# (9992, 'Objeto9992', 'Moda', 485.87, 8, 'Proveedor3', '2023-07-16', 'Almacén A')
# (9993, 'Producto9993', 'Moda', 114.19, 19, 'Proveedor2', '2023-05-26', 'Almacén B')
# (9994, 'Artículo9994', 'Hogar', 404.7, 53, 'Proveedor3', '2023-07-17', 'Almacén A')
# (9995, 'Artículo9995', 'Jardín', 262.34, 35, 'Proveedor3', '2023-01-22', 'Almacén C')
# (9996, 'Objeto9996', 'Moda', 14.84, 17, 'Proveedor3', '2023-12-20', 'Almacén B')
# (9997, 'Producto9997', 'Electrónica', 24.15, 46, 'Proveedor1', '2023-02-05', 'Almacén C')
# (9998, 'Artículo9998', 'Jardín', 190.69, 49, 'Proveedor3', '2023-08-13', 'Almacén A')
# (9999, 'Objeto9999', 'Deportes', 296.62, 76, 'Proveedor1', '2023-11-13', 'Almacén B')
# (10000, 'Producto10000', 'Deportes', 471.85, 1, 'Proveedor3', '2023-06-21', 'Almacén B')

# %% [markdown]
# #PARTE2
# #PREGUNTA1
# Escriba la consulta SQL necesaria para seleccionar únicamente las
# columnas nombre, categoria y precio de todos los productos que pertenecen
# al 'Proveedor1'.
# # Escribir la consulta SQL
# query_proveedor1 = """
# SELECT
#     nombre,
#     categoria,
#     precio
# FROM
#     inventario
# WHERE
#     proveedor = 'Proveedor1';
# """

# %% [markdown]
# ## Realizar consulta y transferir a dataframe

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)

# Cerrar la conexión
conn.close()
# Out:
#         id         nombre categoria  precio  cantidad   proveedor  \
# 0        5      Artículo5      Moda  463.08        16  Proveedor1
# 1        8      Artículo8      Moda  464.74        56  Proveedor2
# 2       10     Artículo10      Moda  470.34        68  Proveedor1
# 3       21     Producto21  Deportes  475.88        48  Proveedor1
# 4       43     Producto43  Deportes  459.22        20  Proveedor2
# ..     ...            ...       ...     ...       ...         ...
# 979   9953     Objeto9953    Jardín  476.10        62  Proveedor2
# 980   9971     Objeto9971      Moda  471.55        46  Proveedor3
# 981   9983     Objeto9983      Moda  487.55        94  Proveedor1
# 982   9992     Objeto9992      Moda  485.87         8  Proveedor3
# 983  10000  Producto10000  Deportes  471.85         1  Proveedor3
#
#     fecha_ingreso  ubicacion
# 0      2023-05-20  Almacén C
# 1      2023-03-20  Almacén A
# 2      2023-12-13  Almacén A
# 3      2023-11-07  Almacén C
# 4      2023-07-02  Almacén A
# ..            ...        ...
# 979    2023-02-09  Almacén C
# 980    2023-06-13  Almacén A
# 981    2023-08-12  Almacén C
# 982    2023-07-16  Almacén A
# 983    2023-06-21  Almacén B
#
# [984 rows x 8 columns]

# %% [markdown]
# #PREGUNTA2
# ¿Qué ventajas ofrece pd.read_sql_query()?
# El método pd.read_sql_query() de Pandas ofrece varias ventajas:
#
# Simplicidad: Ejecuta la consulta y carga los resultados directamente en un DataFrame de Pandas en una sola línea de código.
#
# Conveniencia: Elimina la necesidad de crear un cursor, ejecutar la consulta, usar fetchall() para obtener los datos y luego iterar sobre ellos para procesarlos.
#
# Poder de Análisis: Una vez que los datos están en un DataFrame, puedes usar toda la potencia de la librería Pandas para análisis, manipulación, visualización y limpieza de datos de manera muy sencilla.

# %%
df_productos.head()
# Out:
#    id      nombre categoria  precio  cantidad   proveedor fecha_ingreso  \
# 0   5   Artículo5      Moda  463.08        16  Proveedor1    2023-05-20
# 1   8   Artículo8      Moda  464.74        56  Proveedor2    2023-03-20
# 2  10  Artículo10      Moda  470.34        68  Proveedor1    2023-12-13
# 3  21  Producto21  Deportes  475.88        48  Proveedor1    2023-11-07
# 4  43  Producto43  Deportes  459.22        20  Proveedor2    2023-07-02
#
#    ubicacion
# 0  Almacén C
# 1  Almacén A
# 2  Almacén A
# 3  Almacén C
# 4  Almacén A

# %% [markdown]
# ## Nueva consulta

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450 AND cantidad > 25"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)


# Cerrar la conexión
conn.close()
# Out:
#        id        nombre    categoria  precio  cantidad   proveedor  \
# 0       8     Artículo8         Moda  464.74        56  Proveedor2
# 1      10    Artículo10         Moda  470.34        68  Proveedor1
# 2      21    Producto21     Deportes  475.88        48  Proveedor1
# 3      47    Producto47  Electrónica  498.20        34  Proveedor3
# 4      59    Producto59     Deportes  480.45        74  Proveedor2
# ..    ...           ...          ...     ...       ...         ...
# 730  9921  Artículo9921        Hogar  486.84        88  Proveedor3
# 731  9935  Producto9935       Jardín  477.95        79  Proveedor3
# 732  9953    Objeto9953       Jardín  476.10        62  Proveedor2
# 733  9971    Objeto9971         Moda  471.55        46  Proveedor3
# 734  9983    Objeto9983         Moda  487.55        94  Proveedor1
#
#     fecha_ingreso  ubicacion
# 0      2023-03-20  Almacén A
# 1      2023-12-13  Almacén A
# 2      2023-11-07  Almacén C
# 3      2023-06-20  Almacén A
# 4      2023-04-02  Almacén C
# ..            ...        ...
# 730    2023-05-03  Almacén C
# 731    2023-05-09  Almacén C
# 732    2023-02-09  Almacén C
# 733    2023-06-13  Almacén A
# 734    2023-08-12  Almacén C
#
# [735 rows x 8 columns]

# %% [markdown]
# #PREGUNTA3
# En la sección “Nueva consulta”, modifique la variable query para que, en lugar de mostrar productos con precio > 450 Y cantidad > 25, muestre aquellos que cumplan la condición precio > 480 O cantidad < 5.
# SIMPLEMENTE TENDREMOS QUE CAMBIAR LA SIGUIENTE LINEA DE COMANDO
# query = "SELECT * FROM productos WHERE precio > 480 OR cantidad < 5"

# %% [markdown]
# ## Insertar nuevo producto

# %%
# Datos del nuevo producto
nuevo_producto = (
    None,  # SQLite genera un nuevo id automáticamente si la columna es autoincrement
    'NuevoProducto123',
    'Electrónica',
    249.99,
    20,
    'ProveedorX',
    '2024-04-16',
    'Almacén D'
)

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de nuevo producto
c.execute('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', nuevo_producto)

# Guardar (commit) los cambios y cerrar conexión con la DB
conn.commit()
conn.close()

# %% [markdown]
# #PARTE 3
# #PREGINTA1
# ¿Por qué es una buena práctica de seguridad usar ? como marcador de posición?
#
# Usar ? (marcadores de posición) es la práctica recomendada para pasar valores a una consulta SQL porque previene ataques de inyección SQL. Cuando se usan estos marcadores, la librería de la base de datos se encarga de "sanitizar" los datos, es decir, se asegura de que los valores se traten únicamente como datos y no como parte del comando SQL. Esto evita que un atacante pueda insertar código SQL malicioso en los valores de entrada para manipular o dañar la base de datos.

# %% [markdown]
# ## Insertar nuevo producto desde Excel

# %% [markdown]
# ### Crear tabla excel de nuevos productos

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

np.random.seed(0)
num_prods = 5000

# Productos nuevos
nombres = ['Producto' + str(i) for i in range(num_prods)]
categorias = np.random.choice(['Electrónica', 'Hogar', 'Jardín', 'Moda', 'Deportes'], num_prods)
precios = np.round(np.random.uniform(10.0, 500.0, num_prods), 2)
cantidades = np.random.randint(1, 100, num_prods)
proveedores = np.random.choice(['Proveedor1', 'Proveedor2', 'Proveedor3'], num_prods)
fechas = [datetime.today() - timedelta(days=np.random.randint(0, 365)) for _ in range(num_prods)]
ubicaciones = np.random.choice(['Almacén A', 'Almacén B', 'Almacén C'], num_prods)

# DataFrame
df = pd.DataFrame({
    'Nombre': nombres,
    'Categoría': categorias,
    'Precio': precios,
    'Cantidad': cantidades,
    'Proveedor': proveedores,
    'Fecha de Ingreso': pd.to_datetime(fechas),
    'Ubicación': ubicaciones
})

print(df.head())

# Guardar el DataFrame en un archivo Excel
df.to_excel('nuevos_productos_inventario.xlsx', index=False)
# Out:
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#             Fecha de Ingreso  Ubicación
# 0 2025-06-06 14:54:39.548867  Almacén B
# 1 2025-03-11 14:54:39.548918  Almacén C
# 2 2024-12-17 14:54:39.548935  Almacén B
# 3 2025-08-14 14:54:39.548948  Almacén A
# 4 2024-11-30 14:54:39.549012  Almacén A

# %% [markdown]
# ### Agregar datos de tabla excel al inventario

# %%
import pandas as pd

# Leer archivo Excel
ruta_archivo = '/content/nuevos_productos_inventario.xlsx'
df = pd.read_excel(ruta_archivo)

# Verificación de formatos (tipo de dato)
# Precio a float
if df['Precio'].dtype != 'float':
    df['Precio'] = df['Precio'].astype(float)

# Fecha de Ingreso a datetime
if df['Fecha de Ingreso'].dtype != 'datetime64[ns]':
    df['Fecha de Ingreso'] = pd.to_datetime(df['Fecha de Ingreso'], errors='coerce')

# Verificar y corregir fechas no válidas, usando la fecha de hoy
df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)

df.head()
# Out:
# /tmp/ipython-input-1041989223.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#          Fecha de Ingreso  Ubicación
# 0 2025-06-06 14:54:39.549  Almacén B
# 1 2025-03-11 14:54:39.549  Almacén C
# 2 2024-12-17 14:54:39.549  Almacén B
# 3 2025-08-14 14:54:39.549  Almacén A
# 4 2024-11-30 14:54:39.549  Almacén A

# %% [markdown]
# #PREGUNTA2
# ¿Por qué es fundamental validar los tipos de dato antes de la inserción?
#
# Es fundamental validar y convertir los tipos de datos antes de insertarlos porque las bases de datos tienen esquemas estrictos. Cada columna en la tabla inventario fue definida con un tipo de dato específico (TEXT, DECIMAL, INTEGER, DATE).
#
# Si intentamos insertar un dato con un formato incorrecto (por ejemplo, un texto en una columna de precios o una fecha mal formateada), la base de datos rechazará la operación y generará un error. Realizar la validación en el código de Python permite manejar estos problemas de antemano (por ejemplo, convirtiendo los datos al formato correcto o estableciendo un valor por defecto), garantizando la integridad de los datos y evitando que el programa se detenga por errores inesperados.

# %%
import sqlite3

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de datos en la DB
for index, row in df.iterrows():
    c.execute("""
        INSERT INTO inventario (id, nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?)""", (None, row['Nombre'], row['Categoría'], row['Precio'], row['Cantidad'], row['Proveedor'], str(row['Fecha de Ingreso']), row['Ubicación']))
###CORRECION None,.....###

# # Insersión de datos en la DB
# for index, row in df.iterrows():
#     c.executemany("""
#         INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
#         VALUES(?, ?, ?, ?, ?, ?,)""",
#         [row['Nombre'], row['Categoría'], row['Precio'], row['Cantidad'], row['Proveedor'], row['Fecha de Ingreso'], row['Ubicación']])

# Guardar cambios y cerrar conexión con DB
conn.commit()
conn.close()

print("¡Datos importados exitosamente!")
# Out:
# ¡Datos importados exitosamente!

# %% [markdown]
# #PREGUNTA3
# ¡Error en el código!
#
# A:
# El error se encuentra en la tupla de valores que se pasa al método c.execute():
#
# (row[], row['Nombre'], row['Categoría'], ...)
#
# El primer elemento, row[], es una sintaxis inválida en Python. La intención era pasar un valor para la columna id, pero no se especificó ninguna clave dentro de los corchetes. Además, como el id es autoincremental, no deberíamos intentar asignarle un valor del DataFrame directamente
#
# B: Para corregirlo, debemos reemplazar row[] por None, para indicarle a SQLite que genere automáticamente el valor del id. El bloque de código corregido se vería así:
#
# (None, row['Nombre'], row['Categoría'], row['Precio'], row['Cantidad'], row['Proveedor'], str(row['Fecha de Ingreso']), row['Ubicación']))

# %% [markdown]
# #PARTE 4
# #PREGUNTA1
# optimizacion

# %%
import sqlite3
import pandas as pd

# Leer el archivo Excel y asegurar los tipos de datos (como en la sección anterior)
ruta_archivo = '/content/nuevos_productos_inventario.xlsx'
df = pd.read_excel(ruta_archivo)
df['Precio'] = df['Precio'].astype(float)
df['Fecha de Ingreso'] = pd.to_datetime(df['Fecha de Ingreso'], errors='coerce').fillna(pd.Timestamp.today())
df['Fecha de Ingreso'] = df['Fecha de Ingreso'].dt.strftime('%Y-%m-%d %H:%M:%S') # Convertir fecha a texto para SQLite

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Preparar los datos como una lista de tuplas
# Se agrega 'None' al inicio de cada tupla para el ID autoincremental
datos_para_insertar = [(None,) + tuple(row) for row in df.to_numpy()]

# Usar executemany para una inserción masiva y eficiente
c.executemany("""
    INSERT INTO inventario (id, nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
    VALUES (?, ?, ?, ?, ?, ?, ?, ?)
""", datos_para_insertar)

# Guardar cambios y cerrar conexión
conn.commit()
conn.close()

print(f"¡{len(datos_para_insertar)} nuevos registros importados exitosamente usando executemany!")
# Out:
# ¡5000 nuevos registros importados exitosamente usando executemany!

# %% [markdown]
# #PREGUNTA2
# agregacion

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Consulta SQL para calcular el valor total por categoría y ordenar los resultados
query_valor_total = """
SELECT
    categoria,
    SUM(precio * cantidad) AS valor_total_inventario
FROM
    inventario
GROUP BY
    categoria
ORDER BY
    valor_total_inventario DESC;
"""

# Ejecutar la consulta y cargar los resultados en un DataFrame
df_valor_total = pd.read_sql_query(query_valor_total, conn)

# Formatear la columna de valor para que se vea como moneda (opcional, para mejor visualización)
df_valor_total['valor_total_inventario'] = df_valor_total['valor_total_inventario'].apply(lambda x: f"${x:,.2f}")


# Mostrar el DataFrame con los resultados
print("Valor total del inventario por categoría:")
print(df_valor_total)

# Cerrar la conexión
conn.close()
# Out:
# Valor total del inventario por categoría:
#      categoria valor_total_inventario
# 0        Hogar         $39,898,681.86
# 1         Moda         $39,838,542.90
# 2     Deportes         $38,940,629.59
# 3  Electrónica         $37,209,759.00
# 4       Jardín         $37,147,009.62
